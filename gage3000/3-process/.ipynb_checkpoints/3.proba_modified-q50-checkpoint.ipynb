# %%
#替换了q50_weighted文件，并调整了高点范围，主要是river width和q50时间尺度的匹配。
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
from scipy.optimize import least_squares
import os
import warnings
warnings.filterwarnings('ignore')

R_list = np.array([0.5,1,2,4,8])
GAP_list = np.array([-0.1,0,0.1])
W_list = np.array([0.3,0.5,0.7])

# wse = wse0 + a * width**b
# return array of redisuals
def PowerFunc(params, X, y):
    wse0, a, b = params
    return y - (wse0 + a * X**b)

# soft_l1, z=residual^2
# 'weight' for swot points, low and high point equally divide remaining weight
def Loss(z):
    rho = np.zeros(3*len(z)).reshape(3,-1)
    rho[0] = 2 * ((1 + z)**0.5 - 1)
    rho[1] = (1 + z)**(-0.5)
    rho[2] = -0.5 * (1 + z)**(-1.5)
    rho[:,0] *= (len(z) - 2) / weight * (1 - weight) / 2  # (1-SWOT_weight)/2 for low point
    rho[:,1] *= (len(z) - 2) / weight * (1 - weight) / 2  # (1-SWOT_weight)/2 for high point
    return rho


df_s3all = pd.read_csv('2.swot-points-selection.csv')
df_s3all = df_s3all.drop_duplicates(subset=['stationid','time'], keep='first')
df_attr = pd.read_csv('../2-preprocess/4.q50_weighted_slp.csv')
df_attr = df_attr.drop_duplicates(subset='COMID', keep='first')
df_attr = df_attr.set_index('COMID')

df_w = pd.read_csv('1.width_range.csv', index_col='stationid')
df_s3all= df_s3all[df_s3all['stationid'].isin(df_w.index)]

df_res = df_s3all.drop_duplicates('stationid')
df_res = df_res[['stationid','COMID']]
df_res = pd.concat([df_res]*(len(R_list)*len(GAP_list)*len(W_list)), ignore_index=True)
df_res = df_res.sort_values('stationid')
stationids = df_res['stationid'].unique()
df_res['R'] = R_list[np.tile(np.repeat(np.arange(len(R_list)), len(GAP_list)*len(W_list)), len(stationids))]
df_res['GAP'] = GAP_list[np.tile(np.repeat(np.arange(len(GAP_list)), len(W_list)), len(R_list)*len(stationids))]
df_res['W'] = W_list[np.tile(np.arange(len(W_list)), len(GAP_list)*len(R_list)*len(stationids))]
df_res = df_res.set_index(['stationid','R','GAP','W'])

#breakpoint()
q50, w50, slp, weight = None, None, None, None
for s in stationids[:]:
    print('\r... processing %d/%d ...'%(np.where(stationids==s)[0][0]+1, len(stationids)), end='')
    df_s3: pd.DataFrame = df_s3all[df_s3all['stationid']==s]
    st, comid = df_s3.loc[df_s3.index[0],['stationid','COMID']]
    q50 = df_attr.loc[comid,'q50_weighted']
    slp = df_attr.loc[comid,'slope']
    w50, w_low, w_high = df_w.loc[s,['w50','w_low','w_high']]
    d_bankfull = 0.27 * (w_high / 7.2)**0.6

    # calculate h50
    df_s3['w50_diff'] = np.abs(df_s3['width'] - w50)
    df_s3 = df_s3.sort_values('w50_diff')
    xdata = df_s3.iloc[:5]['width'].values
    ydata = df_s3.iloc[:5]['wse'].values
    xdata_uni = np.unique(df_s3.iloc[:5]['width'].values)  # 选择唯一的宽度值
    if len(xdata_uni) < 2:
        print("无法进行回归，宽度值过于相似")
        print(df_s3)
    else:
        ydata = df_s3.iloc[:5]['wse'].values
        res = linregress(xdata, ydata)
        if res[0] >= 0:
            h50 = res[0] * w50 + res[1]
        else:
            h50 = df_s3.iloc[:5]['wse'].mean()


    # calculate a50, h_low, h_high
    df_s4 = df_s3[(df_s3['width']>=w_low) & (df_s3['width']<=w_high)]
    if len(df_s4) < 3: continue
        
    swot_wsemax = df_s4.sort_values('wse', ascending=False).iloc[0]
    d_wsemax = 0.27 * (swot_wsemax['width'] / 7.2)**0.6
    # solve (a50 / w50)**(2/3) * slp**(1/2) / 0.035 * a50 = q50
    a50 = (q50 * 0.035 / slp**(1/2) * w50**(2/3))**(3/5)

    for r_low in R_list:
        for gap in GAP_list:
            for weight in W_list:
                # suppose channel below median can be approximated by d = a * w**R
                # solve a50 = a * w50**R * w50 - a / (R+1) * w50**(R+1)
                a_low = a50 * (r_low+1) / r_low / w50**(r_low+1)
                h0 = h50 - a_low * w50**r_low
                h_low = h0 + a_low * w_low**r_low
                h_high = swot_wsemax['wse'] + (d_bankfull - d_wsemax) + gap * d_bankfull

                # fit
                xdata = df_s4['width'].values
                ydata = df_s4['wse'].values
                a_default = (h_high - h0) / w_high**2
                xdata = np.insert(xdata, 0, [w_low,w_high])
                ydata = np.insert(ydata, 0, [h_low,h_high])
                try:
                    ls = least_squares(PowerFunc, x0=[h0,a_default,2], loss=Loss, args=(xdata,ydata))
                    status = ls.status
                    if status >0:
                        wse0, a, b = ls.x
                        # 判断是否为不合理拟合（随着x增大，y反而减小）
                        if a * b < 0:
                            print(s)
                            print(f"Unreasonable fit for {s}: a * b = {a * b:.4f}")
                            continue
                        df_res.loc[(s,r_low,gap,weight),['wse0','a','b']] = ls.x
                        df_res.loc[(s,r_low,gap,weight),['a50','w50','q50']] = [a50, w50, q50]
                        df_res.loc[(s,r_low,gap,weight),['w_low','w_high','h_low','h_high','slp']] = [w_low, w_high, h_low, h_high, slp]
                except:
                    breakpoint()
                    

df_res = df_res.dropna()
df_res.to_csv('3.fit_proba_modified_q50.csv')
print('done')
# Out:
# ... processing 8/930 ...Brazil_12180000
# Unreasonable fit for Brazil_12180000: a * b = -9.7942
# Brazil_12180000
# Unreasonable fit for Brazil_12180000: a * b = -9.9952
# Brazil_12180000
# Unreasonable fit for Brazil_12180000: a * b = -9.0486
# Brazil_12180000
# Unreasonable fit for Brazil_12180000: a * b = -9.7020
# ... processing 9/930 ...Brazil_12200000
# Unreasonable fit for Brazil_12200000: a * b = -1.0837
# ... processing 13/930 ...Brazil_12390000
# Unreasonable fit for Brazil_12390000: a * b = -0.1268
# Brazil_12390000
# Unreasonable fit for Brazil_12390000: a * b = -0.1353
# Brazil_12390000
# Unreasonable fit for Brazil_12390000: a * b = -0.1419
# Brazil_12390000
# Unreasonable fit for Brazil_12390000: a * b = -0.1284
# Brazil_12390000
# Unreasonable fit for Brazil_12390000: a * b = -0.1363
# Brazil_12390000
# Unreasonable fit for Brazil_12390000: a * b = -0.1426
# Brazil_12390000
# Unreasonable fit for Brazil_12390000: a * b = -0.1294
# Brazil_12390000
# Unreasonable fit for Brazil_12390000: a * b = -0.1362
# Brazil_12390000
# Unreasonable fit for Brazil_12390000: a * b = -0.1420
# ... processing 22/930 ...Brazil_13710001
# Unreasonable fit for Brazil_13710001: a * b = -0.1981
# Brazil_13710001
# Unreasonable fit for Brazil_13710001: a * b = -0.2023
# Brazil_13710001
# Unreasonable fit for Brazil_13710001: a * b = -0.2058
# Brazil_13710001
# Unreasonable fit for Brazil_13710001: a * b = -0.2047
# Brazil_13710001
# Unreasonable fit for Brazil_13710001: a * b = -0.2084
# Brazil_13710001
# Unreasonable fit for Brazil_13710001: a * b = -0.2116
# Brazil_13710001
# Unreasonable fit for Brazil_13710001: a * b = -0.2109
# Brazil_13710001
# Unreasonable fit for Brazil_13710001: a * b = -0.2137
# Brazil_13710001
# Unreasonable fit for Brazil_13710001: a * b = -0.2163
# Brazil_13710001
# Unreasonable fit for Brazil_13710001: a * b = -0.0713
# Brazil_13710001
# Unreasonable fit for Brazil_13710001: a * b = -0.0075
# Brazil_13710001
# Unreasonable fit for Brazil_13710001: a * b = -0.0263
# Brazil_13710001
# Unreasonable fit for Brazil_13710001: a * b = -0.0101
# ... processing 24/930 ...Brazil_13750000
# Unreasonable fit for Brazil_13750000: a * b = -2.8544
# ... processing 25/930 ...无法进行回归，宽度值过于相似
#           COMID  Unnamed: 0         node_id       lat        lon  \
# 22496  62094091         234  62292400980531 -8.785571 -65.910712
#
#                time       wse    wse_u     width   width_u        stationid  \
# 22496  7.586594e+08  68.61447  0.11091  70.58418  5.167691  Brazil_13848000
#
#        node_data_num  width_u_r  w50_diff
# 22496             85   0.073213  5.769683
# ... processing 27/930 ...Brazil_14230000
# Unreasonable fit for Brazil_14230000: a * b = -4.5442
# Brazil_14230000
# Unreasonable fit for Brazil_14230000: a * b = -0.0695
# Brazil_14230000
# Unreasonable fit for Brazil_14230000: a * b = -0.0515
# Brazil_14230000
# Unreasonable fit for Brazil_14230000: a * b = -0.0488
# Brazil_14230000
# Unreasonable fit for Brazil_14230000: a * b = -0.0386
# ... processing 35/930 ...Brazil_15150000
# Unreasonable fit for Brazil_15150000: a * b = -0.4424
# Brazil_15150000
# Unreasonable fit for Brazil_15150000: a * b = -0.4477
# Brazil_15150000
# Unreasonable fit for Brazil_15150000: a * b = -0.2927
# ... processing 39/930 ...Brazil_15400000
# Unreasonable fit for Brazil_15400000: a * b = -0.0040
# Brazil_15400000
# Unreasonable fit for Brazil_15400000: a * b = -0.0038
# ... processing 54/930 ...Brazil_17122000
# Unreasonable fit for Brazil_17122000: a * b = -0.2234
# Brazil_17122000
# Unreasonable fit for Brazil_17122000: a * b = -0.1738
# Brazil_17122000
# Unreasonable fit for Brazil_17122000: a * b = -0.1392
# ... processing 56/930 ...Brazil_17200000
# Unreasonable fit for Brazil_17200000: a * b = -0.0604
# ... processing 71/930 ...Brazil_21500000
# Unreasonable fit for Brazil_21500000: a * b = -0.8411
# ... processing 78/930 ...Brazil_25200000
# Unreasonable fit for Brazil_25200000: a * b = -0.0116
# Brazil_25200000
# Unreasonable fit for Brazil_25200000: a * b = -0.0102
# ... processing 82/930 ...Brazil_26030000
# Unreasonable fit for Brazil_26030000: a * b = -0.3339
# Brazil_26030000
# Unreasonable fit for Brazil_26030000: a * b = -0.3520
# Brazil_26030000
# Unreasonable fit for Brazil_26030000: a * b = -0.3644
# Brazil_26030000
# Unreasonable fit for Brazil_26030000: a * b = -0.3285
# Brazil_26030000
# Unreasonable fit for Brazil_26030000: a * b = -0.3448
# Brazil_26030000
# Unreasonable fit for Brazil_26030000: a * b = -0.3584
# Brazil_26030000
# Unreasonable fit for Brazil_26030000: a * b = -0.3001
# ... processing 83/930 ...Brazil_26050000
# Unreasonable fit for Brazil_26050000: a * b = -109.4215
# Brazil_26050000
# Unreasonable fit for Brazil_26050000: a * b = -107.1602
# Brazil_26050000
# Unreasonable fit for Brazil_26050000: a * b = -109.4240
# Brazil_26050000
# Unreasonable fit for Brazil_26050000: a * b = -108.7757
# Brazil_26050000
# Unreasonable fit for Brazil_26050000: a * b = -5.2876
# ... processing 87/930 ...Brazil_26300000
# Unreasonable fit for Brazil_26300000: a * b = -0.0115
# Brazil_26300000
# Unreasonable fit for Brazil_26300000: a * b = -0.0128
# ... processing 112/930 ...Brazil_45480000
# Unreasonable fit for Brazil_45480000: a * b = -0.0660
# Brazil_45480000
# Unreasonable fit for Brazil_45480000: a * b = -0.0666
# Brazil_45480000
# Unreasonable fit for Brazil_45480000: a * b = -0.0671
# Brazil_45480000
# Unreasonable fit for Brazil_45480000: a * b = -0.0685
# Brazil_45480000
# Unreasonable fit for Brazil_45480000: a * b = -0.0692
# Brazil_45480000
# Unreasonable fit for Brazil_45480000: a * b = -0.0696
# Brazil_45480000
# Unreasonable fit for Brazil_45480000: a * b = -0.0717
# Brazil_45480000
# Unreasonable fit for Brazil_45480000: a * b = -0.0722
# Brazil_45480000
# Unreasonable fit for Brazil_45480000: a * b = -0.0222
# ... processing 139/930 ...Brazil_58318002
# Unreasonable fit for Brazil_58318002: a * b = -0.0672
# Brazil_58318002
# Unreasonable fit for Brazil_58318002: a * b = -3.5240
# ... processing 148/930 ...Brazil_61855000
# Unreasonable fit for Brazil_61855000: a * b = -0.7612
# Brazil_61855000
# Unreasonable fit for Brazil_61855000: a * b = -0.6796
# Brazil_61855000
# Unreasonable fit for Brazil_61855000: a * b = -0.4817
# Brazil_61855000
# Unreasonable fit for Brazil_61855000: a * b = -0.7445
# Brazil_61855000
# Unreasonable fit for Brazil_61855000: a * b = -0.5374
# Brazil_61855000
# Unreasonable fit for Brazil_61855000: a * b = -0.8059
# Brazil_61855000
# Unreasonable fit for Brazil_61855000: a * b = -0.5941
# ... processing 150/930 ...Brazil_61912000
# Unreasonable fit for Brazil_61912000: a * b = -0.2238
# Brazil_61912000
# Unreasonable fit for Brazil_61912000: a * b = -0.1436
# Brazil_61912000
# Unreasonable fit for Brazil_61912000: a * b = -0.1844
# Brazil_61912000
# Unreasonable fit for Brazil_61912000: a * b = -0.1115
# Brazil_61912000
# Unreasonable fit for Brazil_61912000: a * b = -0.1452
# ... processing 182/930 ...Brazil_66120000
# Unreasonable fit for Brazil_66120000: a * b = -19.6557
# Brazil_66120000
# Unreasonable fit for Brazil_66120000: a * b = -19.7417
# Brazil_66120000
# Unreasonable fit for Brazil_66120000: a * b = -19.8081
# Brazil_66120000
# Unreasonable fit for Brazil_66120000: a * b = -19.7833
# Brazil_66120000
# Unreasonable fit for Brazil_66120000: a * b = -19.8610
# Brazil_66120000
# Unreasonable fit for Brazil_66120000: a * b = -19.9225
# Brazil_66120000
# Unreasonable fit for Brazil_66120000: a * b = -19.9033
# Brazil_66120000
# Unreasonable fit for Brazil_66120000: a * b = -19.9689
# Brazil_66120000
# Unreasonable fit for Brazil_66120000: a * b = -20.0229
# Brazil_66120000
# Unreasonable fit for Brazil_66120000: a * b = -0.5034
# Brazil_66120000
# Unreasonable fit for Brazil_66120000: a * b = -0.6980
# Brazil_66120000
# Unreasonable fit for Brazil_66120000: a * b = -0.5549
# Brazil_66120000
# Unreasonable fit for Brazil_66120000: a * b = -0.6758
# Brazil_66120000
# Unreasonable fit for Brazil_66120000: a * b = -0.5477
# Brazil_66120000
# Unreasonable fit for Brazil_66120000: a * b = -0.6522
# ... processing 189/930 ...Brazil_66800000
# Unreasonable fit for Brazil_66800000: a * b = -5.5387
# Brazil_66800000
# Unreasonable fit for Brazil_66800000: a * b = -5.5314
# Brazil_66800000
# Unreasonable fit for Brazil_66800000: a * b = -5.5297
# Brazil_66800000
# Unreasonable fit for Brazil_66800000: a * b = -5.6340
# Brazil_66800000
# Unreasonable fit for Brazil_66800000: a * b = -5.6261
# Brazil_66800000
# Unreasonable fit for Brazil_66800000: a * b = -5.7270
# ... processing 193/930 ...Brazil_70700000
# Unreasonable fit for Brazil_70700000: a * b = -0.0286
# ... processing 223/930 ...Canada_02AB025
# Unreasonable fit for Canada_02AB025: a * b = -0.3941
# Canada_02AB025
# Unreasonable fit for Canada_02AB025: a * b = -0.1516
# Canada_02AB025
# Unreasonable fit for Canada_02AB025: a * b = -0.1349
# ... processing 232/930 ...Canada_05BH005
# Unreasonable fit for Canada_05BH005: a * b = -0.1897
# Canada_05BH005
# Unreasonable fit for Canada_05BH005: a * b = -0.1489
# Canada_05BH005
# Unreasonable fit for Canada_05BH005: a * b = -0.1836
# Canada_05BH005
# Unreasonable fit for Canada_05BH005: a * b = -0.4399
# Canada_05BH005
# Unreasonable fit for Canada_05BH005: a * b = -0.1762
# ... processing 245/930 ...Canada_05PC019
# Unreasonable fit for Canada_05PC019: a * b = -0.0714
# Canada_05PC019
# Unreasonable fit for Canada_05PC019: a * b = -0.1087
# Canada_05PC019
# Unreasonable fit for Canada_05PC019: a * b = -0.1732
# Canada_05PC019
# Unreasonable fit for Canada_05PC019: a * b = -0.0733
# Canada_05PC019
# Unreasonable fit for Canada_05PC019: a * b = -0.1078
# Canada_05PC019
# Unreasonable fit for Canada_05PC019: a * b = -0.1560
# Canada_05PC019
# Unreasonable fit for Canada_05PC019: a * b = -0.0742
# Canada_05PC019
# Unreasonable fit for Canada_05PC019: a * b = -0.1035
# ... processing 257/930 ...Canada_07FD002
# Unreasonable fit for Canada_07FD002: a * b = -0.0091
# Canada_07FD002
# Unreasonable fit for Canada_07FD002: a * b = -0.0157
# Canada_07FD002
# Unreasonable fit for Canada_07FD002: a * b = -0.0302
# Canada_07FD002
# Unreasonable fit for Canada_07FD002: a * b = -0.0092
# Canada_07FD002
# Unreasonable fit for Canada_07FD002: a * b = -0.0147
# Canada_07FD002
# Unreasonable fit for Canada_07FD002: a * b = -0.0244
# Canada_07FD002
# Unreasonable fit for Canada_07FD002: a * b = -0.0088
# Canada_07FD002
# Unreasonable fit for Canada_07FD002: a * b = -0.0122
# ... processing 267/930 ...Canada_08JA017
# Unreasonable fit for Canada_08JA017: a * b = -0.0488
# Canada_08JA017
# Unreasonable fit for Canada_08JA017: a * b = -0.0792
# Canada_08JA017
# Unreasonable fit for Canada_08JA017: a * b = -0.0685
# Canada_08JA017
# Unreasonable fit for Canada_08JA017: a * b = -0.0587
# ... processing 268/930 ...Canada_08JC001
# Unreasonable fit for Canada_08JC001: a * b = -40.4844
# ... processing 269/930 ...Canada_08JC002
# Unreasonable fit for Canada_08JC002: a * b = -0.2187
# Canada_08JC002
# Unreasonable fit for Canada_08JC002: a * b = -0.1673
# Canada_08JC002
# Unreasonable fit for Canada_08JC002: a * b = -0.1236
# ... processing 273/930 ...Canada_08LB064
# Unreasonable fit for Canada_08LB064: a * b = -9996.2976
# Canada_08LB064
# Unreasonable fit for Canada_08LB064: a * b = -67097.3133
# Canada_08LB064
# Unreasonable fit for Canada_08LB064: a * b = -199015.1975
# Canada_08LB064
# Unreasonable fit for Canada_08LB064: a * b = -11.7927
# ... processing 276/930 ...Canada_08MF005
# Unreasonable fit for Canada_08MF005: a * b = -0.0562
# Canada_08MF005
# Unreasonable fit for Canada_08MF005: a * b = -0.0190
# Canada_08MF005
# Unreasonable fit for Canada_08MF005: a * b = -0.0111
# Canada_08MF005
# Unreasonable fit for Canada_08MF005: a * b = -0.0457
# Canada_08MF005
# Unreasonable fit for Canada_08MF005: a * b = -0.0138
# Canada_08MF005
# Unreasonable fit for Canada_08MF005: a * b = -14.6198
# Canada_08MF005
# Unreasonable fit for Canada_08MF005: a * b = -0.0398
# ... processing 277/930 ...Canada_08MF040
# Unreasonable fit for Canada_08MF040: a * b = -0.0416
# Canada_08MF040
# Unreasonable fit for Canada_08MF040: a * b = -0.0300
# ... processing 280/930 ...Canada_08NA002
# Unreasonable fit for Canada_08NA002: a * b = -0.1880
# Canada_08NA002
# Unreasonable fit for Canada_08NA002: a * b = -0.1487
# Canada_08NA002
# Unreasonable fit for Canada_08NA002: a * b = -0.1554
# Canada_08NA002
# Unreasonable fit for Canada_08NA002: a * b = -0.1167
# ... processing 281/930 ...Canada_08NE049
# Unreasonable fit for Canada_08NE049: a * b = -0.5088
# ... processing 282/930 ...Canada_08NG065
# Unreasonable fit for Canada_08NG065: a * b = -0.0367
# Canada_08NG065
# Unreasonable fit for Canada_08NG065: a * b = -0.0571
# Canada_08NG065
# Unreasonable fit for Canada_08NG065: a * b = -0.0420
# ... processing 284/930 ...Canada_09AB001
# Unreasonable fit for Canada_09AB001: a * b = -0.5615
# ... processing 326/930 ...EWA_9114021
# Unreasonable fit for EWA_9114021: a * b = -0.0060
# EWA_9114021
# Unreasonable fit for EWA_9114021: a * b = -0.0080
# EWA_9114021
# Unreasonable fit for EWA_9114021: a * b = -0.0063
# EWA_9114021
# Unreasonable fit for EWA_9114021: a * b = -0.0084
# EWA_9114021
# Unreasonable fit for EWA_9114021: a * b = -0.0085
# ... processing 345/930 ...GRDC_1159100
# Unreasonable fit for GRDC_1159100: a * b = -0.0519
# ... processing 346/930 ...GRDC_1159500
# Unreasonable fit for GRDC_1159500: a * b = -0.0480
# GRDC_1159500
# Unreasonable fit for GRDC_1159500: a * b = -0.0475
# ... processing 350/930 ...GRDC_1257100
# Unreasonable fit for GRDC_1257100: a * b = -1.2947
# GRDC_1257100
# Unreasonable fit for GRDC_1257100: a * b = -1.7710
# GRDC_1257100
# Unreasonable fit for GRDC_1257100: a * b = -1.3265
# GRDC_1257100
# Unreasonable fit for GRDC_1257100: a * b = -1.7709
# GRDC_1257100
# Unreasonable fit for GRDC_1257100: a * b = -1.3462
# GRDC_1257100
# Unreasonable fit for GRDC_1257100: a * b = -1.7391
# GRDC_1257100
# Unreasonable fit for GRDC_1257100: a * b = -0.1471
# GRDC_1257100
# Unreasonable fit for GRDC_1257100: a * b = -0.1663
# GRDC_1257100
# Unreasonable fit for GRDC_1257100: a * b = -0.1780
# ... processing 358/930 ...GRDC_1734500
# Unreasonable fit for GRDC_1734500: a * b = -0.2294
# GRDC_1734500
# Unreasonable fit for GRDC_1734500: a * b = -0.2077
# GRDC_1734500
# Unreasonable fit for GRDC_1734500: a * b = -0.1951
# GRDC_1734500
# Unreasonable fit for GRDC_1734500: a * b = -0.1902
# GRDC_1734500
# Unreasonable fit for GRDC_1734500: a * b = -0.1371
# GRDC_1734500
# Unreasonable fit for GRDC_1734500: a * b = -0.1280
# GRDC_1734500
# Unreasonable fit for GRDC_1734500: a * b = -0.1268
# GRDC_1734500
# Unreasonable fit for GRDC_1734500: a * b = -0.1461
# GRDC_1734500
# Unreasonable fit for GRDC_1734500: a * b = -0.1386
# GRDC_1734500
# Unreasonable fit for GRDC_1734500: a * b = -0.1375
# GRDC_1734500
# Unreasonable fit for GRDC_1734500: a * b = -0.1685
# GRDC_1734500
# Unreasonable fit for GRDC_1734500: a * b = -0.1692
# GRDC_1734500
# Unreasonable fit for GRDC_1734500: a * b = -0.1711
# GRDC_1734500
# Unreasonable fit for GRDC_1734500: a * b = -0.1133
# GRDC_1734500
# Unreasonable fit for GRDC_1734500: a * b = -0.1150
# GRDC_1734500
# Unreasonable fit for GRDC_1734500: a * b = -0.1294
# GRDC_1734500
# Unreasonable fit for GRDC_1734500: a * b = -0.1325
# GRDC_1734500
# Unreasonable fit for GRDC_1734500: a * b = -0.1354
# GRDC_1734500
# Unreasonable fit for GRDC_1734500: a * b = -0.1392
# GRDC_1734500
# Unreasonable fit for GRDC_1734500: a * b = -0.1436
# GRDC_1734500
# Unreasonable fit for GRDC_1734500: a * b = -0.1470
# GRDC_1734500
# Unreasonable fit for GRDC_1734500: a * b = -0.0718
# GRDC_1734500
# Unreasonable fit for GRDC_1734500: a * b = -0.0594
# GRDC_1734500
# Unreasonable fit for GRDC_1734500: a * b = -0.0571
# ... processing 364/930 ...GRDC_1834110
# Unreasonable fit for GRDC_1834110: a * b = -2.2089
# ... processing 366/930 ...GRDC_2180712
# Unreasonable fit for GRDC_2180712: a * b = -0.0460
# GRDC_2180712
# Unreasonable fit for GRDC_2180712: a * b = -0.0680
# GRDC_2180712
# Unreasonable fit for GRDC_2180712: a * b = -0.1013
# GRDC_2180712
# Unreasonable fit for GRDC_2180712: a * b = -0.0383
# GRDC_2180712
# Unreasonable fit for GRDC_2180712: a * b = -0.0528
# GRDC_2180712
# Unreasonable fit for GRDC_2180712: a * b = -0.0749
# GRDC_2180712
# Unreasonable fit for GRDC_2180712: a * b = -0.0295
# GRDC_2180712
# Unreasonable fit for GRDC_2180712: a * b = -0.0371
# GRDC_2180712
# Unreasonable fit for GRDC_2180712: a * b = -0.0511
# ... processing 390/930 ...GRDC_2588552
# Unreasonable fit for GRDC_2588552: a * b = -0.0171
# ... processing 404/930 ...GRDC_2589502
# Unreasonable fit for GRDC_2589502: a * b = -1.1886
# GRDC_2589502
# Unreasonable fit for GRDC_2589502: a * b = -1.1542
# GRDC_2589502
# Unreasonable fit for GRDC_2589502: a * b = -1.1596
# GRDC_2589502
# Unreasonable fit for GRDC_2589502: a * b = -1.1794
# GRDC_2589502
# Unreasonable fit for GRDC_2589502: a * b = -1.1205
# GRDC_2589502
# Unreasonable fit for GRDC_2589502: a * b = -1.1288
# GRDC_2589502
# Unreasonable fit for GRDC_2589502: a * b = -1.1651
# GRDC_2589502
# Unreasonable fit for GRDC_2589502: a * b = -1.0740
# GRDC_2589502
# Unreasonable fit for GRDC_2589502: a * b = -1.0881
# GRDC_2589502
# Unreasonable fit for GRDC_2589502: a * b = -0.2549
# GRDC_2589502
# Unreasonable fit for GRDC_2589502: a * b = -0.2479
# GRDC_2589502
# Unreasonable fit for GRDC_2589502: a * b = -0.2367
# ... processing 420/930 ...GRDC_2907400
# Unreasonable fit for GRDC_2907400: a * b = -0.2180
# ... processing 431/930 ...GRDC_3106300
# Unreasonable fit for GRDC_3106300: a * b = -0.0565
# GRDC_3106300
# Unreasonable fit for GRDC_3106300: a * b = -0.0615
# GRDC_3106300
# Unreasonable fit for GRDC_3106300: a * b = -0.0660
# ... processing 446/930 ...GRDC_3627650
# Unreasonable fit for GRDC_3627650: a * b = -0.0283
# ... processing 447/930 ...GRDC_3629000
# Unreasonable fit for GRDC_3629000: a * b = -0.4008
# ... processing 448/930 ...GRDC_3629380
# Unreasonable fit for GRDC_3629380: a * b = -0.1973
# ... processing 457/930 ...GRDC_3649614
# Unreasonable fit for GRDC_3649614: a * b = -2.0464
# GRDC_3649614
# Unreasonable fit for GRDC_3649614: a * b = -1.9281
# GRDC_3649614
# Unreasonable fit for GRDC_3649614: a * b = -1.8669
# GRDC_3649614
# Unreasonable fit for GRDC_3649614: a * b = -2.0600
# GRDC_3649614
# Unreasonable fit for GRDC_3649614: a * b = -1.8939
# GRDC_3649614
# Unreasonable fit for GRDC_3649614: a * b = -1.7830
# GRDC_3649614
# Unreasonable fit for GRDC_3649614: a * b = -2.0742
# GRDC_3649614
# Unreasonable fit for GRDC_3649614: a * b = -1.8496
# GRDC_3649614
# Unreasonable fit for GRDC_3649614: a * b = -1.6741
# GRDC_3649614
# Unreasonable fit for GRDC_3649614: a * b = -0.2362
# GRDC_3649614
# Unreasonable fit for GRDC_3649614: a * b = -0.2067
# GRDC_3649614
# Unreasonable fit for GRDC_3649614: a * b = -0.1584
# ... processing 465/930 ...GRDC_4102700
# Unreasonable fit for GRDC_4102700: a * b = -0.0106
# ... processing 467/930 ...GRDC_4102800
# Unreasonable fit for GRDC_4102800: a * b = -174.2840
# GRDC_4102800
# Unreasonable fit for GRDC_4102800: a * b = -170.7421
# GRDC_4102800
# Unreasonable fit for GRDC_4102800: a * b = -167.9287
# GRDC_4102800
# Unreasonable fit for GRDC_4102800: a * b = -173.3851
# GRDC_4102800
# Unreasonable fit for GRDC_4102800: a * b = -171.2544
# GRDC_4102800
# Unreasonable fit for GRDC_4102800: a * b = -167.4690
# GRDC_4102800
# Unreasonable fit for GRDC_4102800: a * b = -172.9116
# GRDC_4102800
# Unreasonable fit for GRDC_4102800: a * b = -169.4974
# GRDC_4102800
# Unreasonable fit for GRDC_4102800: a * b = -0.0014
# GRDC_4102800
# Unreasonable fit for GRDC_4102800: a * b = -166.4185
# GRDC_4102800
# Unreasonable fit for GRDC_4102800: a * b = -170.3954
# GRDC_4102800
# Unreasonable fit for GRDC_4102800: a * b = -166.4744
# GRDC_4102800
# Unreasonable fit for GRDC_4102800: a * b = -166.3324
# ... processing 472/930 ...GRDC_4115202
# Unreasonable fit for GRDC_4115202: a * b = -0.1772
# ... processing 474/930 ...GRDC_4115206
# Unreasonable fit for GRDC_4115206: a * b = -0.0949
# ... processing 479/930 ...GRDC_4119800
# Unreasonable fit for GRDC_4119800: a * b = -0.0186
# GRDC_4119800
# Unreasonable fit for GRDC_4119800: a * b = -0.0186
# GRDC_4119800
# Unreasonable fit for GRDC_4119800: a * b = -0.0203
# GRDC_4119800
# Unreasonable fit for GRDC_4119800: a * b = -0.0203
# GRDC_4119800
# Unreasonable fit for GRDC_4119800: a * b = -0.0204
# GRDC_4119800
# Unreasonable fit for GRDC_4119800: a * b = -0.0220
# GRDC_4119800
# Unreasonable fit for GRDC_4119800: a * b = -0.0221
# GRDC_4119800
# Unreasonable fit for GRDC_4119800: a * b = -0.0221
# GRDC_4119800
# Unreasonable fit for GRDC_4119800: a * b = -0.0006
# GRDC_4119800
# Unreasonable fit for GRDC_4119800: a * b = -0.0006
# GRDC_4119800
# Unreasonable fit for GRDC_4119800: a * b = -0.0007
# GRDC_4119800
# Unreasonable fit for GRDC_4119800: a * b = -0.0007
# GRDC_4119800
# Unreasonable fit for GRDC_4119800: a * b = -0.0008
# ... processing 484/930 ...GRDC_4121801
# Unreasonable fit for GRDC_4121801: a * b = -0.2215
# GRDC_4121801
# Unreasonable fit for GRDC_4121801: a * b = -0.1519
# GRDC_4121801
# Unreasonable fit for GRDC_4121801: a * b = -0.1402
# GRDC_4121801
# Unreasonable fit for GRDC_4121801: a * b = -0.1551
# GRDC_4121801
# Unreasonable fit for GRDC_4121801: a * b = -0.1029
# GRDC_4121801
# Unreasonable fit for GRDC_4121801: a * b = -0.0952
# GRDC_4121801
# Unreasonable fit for GRDC_4121801: a * b = -0.1160
# GRDC_4121801
# Unreasonable fit for GRDC_4121801: a * b = -0.0755
# GRDC_4121801
# Unreasonable fit for GRDC_4121801: a * b = -0.0702
# ... processing 490/930 ...GRDC_4122650
# Unreasonable fit for GRDC_4122650: a * b = -8.8031
# GRDC_4122650
# Unreasonable fit for GRDC_4122650: a * b = -9.2525
# GRDC_4122650
# Unreasonable fit for GRDC_4122650: a * b = -9.2739
# ... processing 494/930 ...GRDC_4122903
# Unreasonable fit for GRDC_4122903: a * b = -0.0609
# GRDC_4122903
# Unreasonable fit for GRDC_4122903: a * b = -0.0693
# GRDC_4122903
# Unreasonable fit for GRDC_4122903: a * b = -0.0725
# ... processing 495/930 ...GRDC_4123061
# Unreasonable fit for GRDC_4123061: a * b = -0.4757
# ... processing 507/930 ...GRDC_4125901
# Unreasonable fit for GRDC_4125901: a * b = -0.1797
# GRDC_4125901
# Unreasonable fit for GRDC_4125901: a * b = -0.1212
# GRDC_4125901
# Unreasonable fit for GRDC_4125901: a * b = -0.1357
# GRDC_4125901
# Unreasonable fit for GRDC_4125901: a * b = -0.0874
# GRDC_4125901
# Unreasonable fit for GRDC_4125901: a * b = -0.1045
# GRDC_4125901
# Unreasonable fit for GRDC_4125901: a * b = -0.0653
# ... processing 511/930 ...GRDC_4126806
# Unreasonable fit for GRDC_4126806: a * b = -0.0670
# GRDC_4126806
# Unreasonable fit for GRDC_4126806: a * b = -0.0216
# GRDC_4126806
# Unreasonable fit for GRDC_4126806: a * b = -0.0240
# GRDC_4126806
# Unreasonable fit for GRDC_4126806: a * b = -0.0255
# ... processing 541/930 ...GRDC_4203900
# Unreasonable fit for GRDC_4203900: a * b = -0.0945
# GRDC_4203900
# Unreasonable fit for GRDC_4203900: a * b = -0.0837
# GRDC_4203900
# Unreasonable fit for GRDC_4203900: a * b = -0.0718
# GRDC_4203900
# Unreasonable fit for GRDC_4203900: a * b = -0.0913
# GRDC_4203900
# Unreasonable fit for GRDC_4203900: a * b = -0.0745
# GRDC_4203900
# Unreasonable fit for GRDC_4203900: a * b = -0.0581
# GRDC_4203900
# Unreasonable fit for GRDC_4203900: a * b = -0.0873
# GRDC_4203900
# Unreasonable fit for GRDC_4203900: a * b = -0.0638
# GRDC_4203900
# Unreasonable fit for GRDC_4203900: a * b = -0.0450
# ... processing 543/930 ...GRDC_4204100
# Unreasonable fit for GRDC_4204100: a * b = -0.0561
# GRDC_4204100
# Unreasonable fit for GRDC_4204100: a * b = -10.1895
# ... processing 554/930 ...GRDC_4208220
# Unreasonable fit for GRDC_4208220: a * b = -0.0614
# ... processing 568/930 ...GRDC_4208458
# Unreasonable fit for GRDC_4208458: a * b = -0.3032
# ... processing 581/930 ...GRDC_4214350
# Unreasonable fit for GRDC_4214350: a * b = -0.0958
# GRDC_4214350
# Unreasonable fit for GRDC_4214350: a * b = -0.0718
# ... processing 589/930 ...GRDC_4214610
# Unreasonable fit for GRDC_4214610: a * b = -1.9917
# GRDC_4214610
# Unreasonable fit for GRDC_4214610: a * b = -2.0568
# ... processing 598/930 ...GRDC_4215210
# Unreasonable fit for GRDC_4215210: a * b = -7.9722
# GRDC_4215210
# Unreasonable fit for GRDC_4215210: a * b = -8.0254
# GRDC_4215210
# Unreasonable fit for GRDC_4215210: a * b = -8.0649
# GRDC_4215210
# Unreasonable fit for GRDC_4215210: a * b = -8.0778
# GRDC_4215210
# Unreasonable fit for GRDC_4215210: a * b = -8.1305
# GRDC_4215210
# Unreasonable fit for GRDC_4215210: a * b = -8.1700
# GRDC_4215210
# Unreasonable fit for GRDC_4215210: a * b = -8.1830
# GRDC_4215210
# Unreasonable fit for GRDC_4215210: a * b = -8.2352
# GRDC_4215210
# Unreasonable fit for GRDC_4215210: a * b = -8.2747
# ... processing 600/930 ...GRDC_4215320
# Unreasonable fit for GRDC_4215320: a * b = -2.2318
# GRDC_4215320
# Unreasonable fit for GRDC_4215320: a * b = -2.7991
# GRDC_4215320
# Unreasonable fit for GRDC_4215320: a * b = -1.5752
# ... processing 615/930 ...GRDC_4359320
# Unreasonable fit for GRDC_4359320: a * b = -0.2224
# GRDC_4359320
# Unreasonable fit for GRDC_4359320: a * b = -0.2346
# GRDC_4359320
# Unreasonable fit for GRDC_4359320: a * b = -0.2458
# GRDC_4359320
# Unreasonable fit for GRDC_4359320: a * b = -0.2256
# GRDC_4359320
# Unreasonable fit for GRDC_4359320: a * b = -0.2356
# GRDC_4359320
# Unreasonable fit for GRDC_4359320: a * b = -0.2459
# GRDC_4359320
# Unreasonable fit for GRDC_4359320: a * b = -0.2337
# GRDC_4359320
# Unreasonable fit for GRDC_4359320: a * b = -0.2420
# ... processing 617/930 ...GRDC_4362600
# Unreasonable fit for GRDC_4362600: a * b = -0.6956
# GRDC_4362600
# Unreasonable fit for GRDC_4362600: a * b = -0.4659
# GRDC_4362600
# Unreasonable fit for GRDC_4362600: a * b = -0.2498
# ... processing 631/930 ...GRDC_6242100
# Unreasonable fit for GRDC_6242100: a * b = -0.0172
# ... processing 634/930 ...GRDC_6243030
# Unreasonable fit for GRDC_6243030: a * b = -0.4587
# GRDC_6243030
# Unreasonable fit for GRDC_6243030: a * b = -0.3125
# GRDC_6243030
# Unreasonable fit for GRDC_6243030: a * b = -0.4364
# GRDC_6243030
# Unreasonable fit for GRDC_6243030: a * b = -0.2872
# GRDC_6243030
# Unreasonable fit for GRDC_6243030: a * b = -0.4167
# GRDC_6243030
# Unreasonable fit for GRDC_6243030: a * b = -0.2655
# ... processing 638/930 ...GRDC_6335060
# Unreasonable fit for GRDC_6335060: a * b = -0.0138
# ... processing 642/930 ...GRDC_6335170
# Unreasonable fit for GRDC_6335170: a * b = -0.1714
# GRDC_6335170
# Unreasonable fit for GRDC_6335170: a * b = -0.1423
# ... processing 652/930 ...GRDC_6340130
# Unreasonable fit for GRDC_6340130: a * b = -0.2526
# GRDC_6340130
# Unreasonable fit for GRDC_6340130: a * b = -0.1528
# GRDC_6340130
# Unreasonable fit for GRDC_6340130: a * b = -0.1287
# GRDC_6340130
# Unreasonable fit for GRDC_6340130: a * b = -0.2432
# GRDC_6340130
# Unreasonable fit for GRDC_6340130: a * b = -0.1409
# GRDC_6340130
# Unreasonable fit for GRDC_6340130: a * b = -0.1164
# GRDC_6340130
# Unreasonable fit for GRDC_6340130: a * b = -0.2362
# GRDC_6340130
# Unreasonable fit for GRDC_6340130: a * b = -0.1318
# GRDC_6340130
# Unreasonable fit for GRDC_6340130: a * b = -0.1065
# ... processing 653/930 ...GRDC_6340140
# Unreasonable fit for GRDC_6340140: a * b = -0.0353
# GRDC_6340140
# Unreasonable fit for GRDC_6340140: a * b = -0.0264
# GRDC_6340140
# Unreasonable fit for GRDC_6340140: a * b = -0.0207
# GRDC_6340140
# Unreasonable fit for GRDC_6340140: a * b = -0.0309
# GRDC_6340140
# Unreasonable fit for GRDC_6340140: a * b = -0.0202
# GRDC_6340140
# Unreasonable fit for GRDC_6340140: a * b = -0.0237
# ... processing 656/930 ...GRDC_6340170
# Unreasonable fit for GRDC_6340170: a * b = -0.0933
# GRDC_6340170
# Unreasonable fit for GRDC_6340170: a * b = -0.0953
# GRDC_6340170
# Unreasonable fit for GRDC_6340170: a * b = -0.0720
# ... processing 659/930 ...GRDC_6342600
# Unreasonable fit for GRDC_6342600: a * b = -0.6448
# GRDC_6342600
# Unreasonable fit for GRDC_6342600: a * b = -0.7997
# ... processing 665/930 ...GRDC_6343500
# Unreasonable fit for GRDC_6343500: a * b = -0.2364
# GRDC_6343500
# Unreasonable fit for GRDC_6343500: a * b = -0.1651
# GRDC_6343500
# Unreasonable fit for GRDC_6343500: a * b = -0.2133
# GRDC_6343500
# Unreasonable fit for GRDC_6343500: a * b = -0.1109
# ... processing 675/930 ...GRDC_6442600
# Unreasonable fit for GRDC_6442600: a * b = -0.0319
# GRDC_6442600
# Unreasonable fit for GRDC_6442600: a * b = -0.0190
# ... processing 678/930 ...GRDC_6444310
# Unreasonable fit for GRDC_6444310: a * b = -0.2792
# GRDC_6444310
# Unreasonable fit for GRDC_6444310: a * b = -0.1980
# GRDC_6444310
# Unreasonable fit for GRDC_6444310: a * b = -0.2760
# GRDC_6444310
# Unreasonable fit for GRDC_6444310: a * b = -0.5475
# GRDC_6444310
# Unreasonable fit for GRDC_6444310: a * b = -0.2592
# ... processing 679/930 ...GRDC_6542200
# Unreasonable fit for GRDC_6542200: a * b = -0.0095
# GRDC_6542200
# Unreasonable fit for GRDC_6542200: a * b = -0.0056
# GRDC_6542200
# Unreasonable fit for GRDC_6542200: a * b = -0.0050
# GRDC_6542200
# Unreasonable fit for GRDC_6542200: a * b = -0.0103
# GRDC_6542200
# Unreasonable fit for GRDC_6542200: a * b = -37.3980
# ... processing 680/930 ...GRDC_6544100
# Unreasonable fit for GRDC_6544100: a * b = -5.5247
# ... processing 681/930 ...GRDC_6545800
# Unreasonable fit for GRDC_6545800: a * b = -4.5333
# GRDC_6545800
# Unreasonable fit for GRDC_6545800: a * b = -4.4449
# GRDC_6545800
# Unreasonable fit for GRDC_6545800: a * b = -0.1464
# GRDC_6545800
# Unreasonable fit for GRDC_6545800: a * b = -0.1139
# GRDC_6545800
# Unreasonable fit for GRDC_6545800: a * b = -0.1427
# GRDC_6545800
# Unreasonable fit for GRDC_6545800: a * b = -0.0881
# GRDC_6545800
# Unreasonable fit for GRDC_6545800: a * b = -0.0651
# GRDC_6545800
# Unreasonable fit for GRDC_6545800: a * b = -0.0889
# ... processing 682/930 ...GRDC_6546802
# Unreasonable fit for GRDC_6546802: a * b = -0.2079
# GRDC_6546802
# Unreasonable fit for GRDC_6546802: a * b = -0.3116
# GRDC_6546802
# Unreasonable fit for GRDC_6546802: a * b = -0.3306
# GRDC_6546802
# Unreasonable fit for GRDC_6546802: a * b = -0.2246
# GRDC_6546802
# Unreasonable fit for GRDC_6546802: a * b = -0.3186
# GRDC_6546802
# Unreasonable fit for GRDC_6546802: a * b = -0.3376
# GRDC_6546802
# Unreasonable fit for GRDC_6546802: a * b = -0.2427
# GRDC_6546802
# Unreasonable fit for GRDC_6546802: a * b = -0.3256
# GRDC_6546802
# Unreasonable fit for GRDC_6546802: a * b = -0.3446
# GRDC_6546802
# Unreasonable fit for GRDC_6546802: a * b = -0.2238
# GRDC_6546802
# Unreasonable fit for GRDC_6546802: a * b = -0.1431
# GRDC_6546802
# Unreasonable fit for GRDC_6546802: a * b = -0.1747
# GRDC_6546802
# Unreasonable fit for GRDC_6546802: a * b = -3.5361
# GRDC_6546802
# Unreasonable fit for GRDC_6546802: a * b = -0.1743
# GRDC_6546802
# Unreasonable fit for GRDC_6546802: a * b = -0.1345
# GRDC_6546802
# Unreasonable fit for GRDC_6546802: a * b = -2.7461
# ... processing 705/930 ...GRDC_6935301
# Unreasonable fit for GRDC_6935301: a * b = -0.6025
# GRDC_6935301
# Unreasonable fit for GRDC_6935301: a * b = -0.9610
# GRDC_6935301
# Unreasonable fit for GRDC_6935301: a * b = -1.5373
# GRDC_6935301
# Unreasonable fit for GRDC_6935301: a * b = -0.6350
# GRDC_6935301
# Unreasonable fit for GRDC_6935301: a * b = -0.9974
# GRDC_6935301
# Unreasonable fit for GRDC_6935301: a * b = -1.5640
# GRDC_6935301
# Unreasonable fit for GRDC_6935301: a * b = -0.6659
# GRDC_6935301
# Unreasonable fit for GRDC_6935301: a * b = -1.0311
# GRDC_6935301
# Unreasonable fit for GRDC_6935301: a * b = -1.5897
# GRDC_6935301
# Unreasonable fit for GRDC_6935301: a * b = -0.1281
# GRDC_6935301
# Unreasonable fit for GRDC_6935301: a * b = -0.1500
# GRDC_6935301
# Unreasonable fit for GRDC_6935301: a * b = -0.1715
# ... processing 711/930 ...GRDC_6974350
# Unreasonable fit for GRDC_6974350: a * b = -2.1242
# GRDC_6974350
# Unreasonable fit for GRDC_6974350: a * b = -1.6459
# GRDC_6974350
# Unreasonable fit for GRDC_6974350: a * b = -1.4304
# GRDC_6974350
# Unreasonable fit for GRDC_6974350: a * b = -1.9552
# GRDC_6974350
# Unreasonable fit for GRDC_6974350: a * b = -1.7563
# ... processing 738/930 ...USGS_01533400
# Unreasonable fit for USGS_01533400: a * b = -0.0583
# USGS_01533400
# Unreasonable fit for USGS_01533400: a * b = -0.0657
# USGS_01533400
# Unreasonable fit for USGS_01533400: a * b = -0.0698
# USGS_01533400
# Unreasonable fit for USGS_01533400: a * b = -0.0576
# USGS_01533400
# Unreasonable fit for USGS_01533400: a * b = -0.0613
# USGS_01533400
# Unreasonable fit for USGS_01533400: a * b = -0.0625
# USGS_01533400
# Unreasonable fit for USGS_01533400: a * b = -0.0552
# USGS_01533400
# Unreasonable fit for USGS_01533400: a * b = -0.0532
# USGS_01533400
# Unreasonable fit for USGS_01533400: a * b = -0.0482
# ... processing 739/930 ...USGS_01536500
# Unreasonable fit for USGS_01536500: a * b = -0.0181
# USGS_01536500
# Unreasonable fit for USGS_01536500: a * b = -0.0272
# USGS_01536500
# Unreasonable fit for USGS_01536500: a * b = -0.0247
# USGS_01536500
# Unreasonable fit for USGS_01536500: a * b = -0.0226
# ... processing 746/930 ...USGS_01638500
# Unreasonable fit for USGS_01638500: a * b = -0.1412
# USGS_01638500
# Unreasonable fit for USGS_01638500: a * b = -0.0359
# ... processing 753/930 ...USGS_02129000
# Unreasonable fit for USGS_02129000: a * b = -0.0523
# ... processing 756/930 ...USGS_02147000
# Unreasonable fit for USGS_02147000: a * b = -0.0443
# ... processing 777/930 ...USGS_02419890
# Unreasonable fit for USGS_02419890: a * b = -0.2269
# ... processing 806/930 ...USGS_03316500
# Unreasonable fit for USGS_03316500: a * b = -2.4775
# USGS_03316500
# Unreasonable fit for USGS_03316500: a * b = -2.5737
# USGS_03316500
# Unreasonable fit for USGS_03316500: a * b = -2.6410
# USGS_03316500
# Unreasonable fit for USGS_03316500: a * b = -2.5135
# USGS_03316500
# Unreasonable fit for USGS_03316500: a * b = -2.6094
# USGS_03316500
# Unreasonable fit for USGS_03316500: a * b = -2.6767
# USGS_03316500
# Unreasonable fit for USGS_03316500: a * b = -2.5495
# USGS_03316500
# Unreasonable fit for USGS_03316500: a * b = -2.6451
# USGS_03316500
# Unreasonable fit for USGS_03316500: a * b = -2.7122
# USGS_03316500
# Unreasonable fit for USGS_03316500: a * b = -0.4253
# USGS_03316500
# Unreasonable fit for USGS_03316500: a * b = -0.4025
# USGS_03316500
# Unreasonable fit for USGS_03316500: a * b = -0.3270
# USGS_03316500
# Unreasonable fit for USGS_03316500: a * b = -0.3526
# USGS_03316500
# Unreasonable fit for USGS_03316500: a * b = -0.3317
# USGS_03316500
# Unreasonable fit for USGS_03316500: a * b = -0.2687
# USGS_03316500
# Unreasonable fit for USGS_03316500: a * b = -0.2899
# USGS_03316500
# Unreasonable fit for USGS_03316500: a * b = -0.2715
# USGS_03316500
# Unreasonable fit for USGS_03316500: a * b = -0.2208
# ... processing 807/930 ...USGS_03320000
# Unreasonable fit for USGS_03320000: a * b = -1.9146
# USGS_03320000
# Unreasonable fit for USGS_03320000: a * b = -1.9247
# USGS_03320000
# Unreasonable fit for USGS_03320000: a * b = -1.6901
# ... processing 810/930 ...USGS_03336000
# Unreasonable fit for USGS_03336000: a * b = -0.0752
# USGS_03336000
# Unreasonable fit for USGS_03336000: a * b = -0.0758
# ... processing 820/930 ...USGS_03470500
# Unreasonable fit for USGS_03470500: a * b = -0.2384
# USGS_03470500
# Unreasonable fit for USGS_03470500: a * b = -0.2237
# USGS_03470500
# Unreasonable fit for USGS_03470500: a * b = -0.2015
# ... processing 835/930 ...USGS_04246500
# Unreasonable fit for USGS_04246500: a * b = -0.2486
# USGS_04246500
# Unreasonable fit for USGS_04246500: a * b = -0.1552
# ... processing 843/930 ...USGS_05440700
# Unreasonable fit for USGS_05440700: a * b = -0.1322
# USGS_05440700
# Unreasonable fit for USGS_05440700: a * b = -0.0855
# USGS_05440700
# Unreasonable fit for USGS_05440700: a * b = -0.1428
# USGS_05440700
# Unreasonable fit for USGS_05440700: a * b = -0.0723
# ... processing 861/930 ...USGS_05568500
# Unreasonable fit for USGS_05568500: a * b = -0.7277
# USGS_05568500
# Unreasonable fit for USGS_05568500: a * b = -0.7212
# USGS_05568500
# Unreasonable fit for USGS_05568500: a * b = -0.7161
# USGS_05568500
# Unreasonable fit for USGS_05568500: a * b = -0.6729
# USGS_05568500
# Unreasonable fit for USGS_05568500: a * b = -0.7313
# USGS_05568500
# Unreasonable fit for USGS_05568500: a * b = -0.6539
# USGS_05568500
# Unreasonable fit for USGS_05568500: a * b = -0.5232
# ... processing 887/930 ...USGS_08028500
# Unreasonable fit for USGS_08028500: a * b = -0.1206
# USGS_08028500
# Unreasonable fit for USGS_08028500: a * b = -0.1278
# USGS_08028500
# Unreasonable fit for USGS_08028500: a * b = -0.1108
# USGS_08028500
# Unreasonable fit for USGS_08028500: a * b = -0.1142
# USGS_08028500
# Unreasonable fit for USGS_08028500: a * b = -0.0967
# ... processing 899/930 ...无法进行回归，宽度值过于相似
#          COMID  Unnamed: 0         node_id        lat         lon  \
# 2928  77029062          46  77222300020841  33.807332 -111.662351
#
#               time        wse    wse_u     width   width_u      stationid  \
# 2928  7.464780e+08  490.74091  0.30363  4.855432  0.284863  USGS_09510000
#
#       node_data_num  width_u_r   w50_diff
# 2928            175   0.058669  57.063906
# ... processing 900/930 ...USGS_11377100
# Unreasonable fit for USGS_11377100: a * b = -0.1048
# USGS_11377100
# Unreasonable fit for USGS_11377100: a * b = -13.2823
# ... processing 914/930 ...USGS_13062500
# Unreasonable fit for USGS_13062500: a * b = -0.0906
# USGS_13062500
# Unreasonable fit for USGS_13062500: a * b = -0.1312
# USGS_13062500
# Unreasonable fit for USGS_13062500: a * b = -0.1987
# USGS_13062500
# Unreasonable fit for USGS_13062500: a * b = -0.0947
# USGS_13062500
# Unreasonable fit for USGS_13062500: a * b = -0.1352
# USGS_13062500
# Unreasonable fit for USGS_13062500: a * b = -0.2015
# USGS_13062500
# Unreasonable fit for USGS_13062500: a * b = -0.0982
# USGS_13062500
# Unreasonable fit for USGS_13062500: a * b = -0.1379
# USGS_13062500
# Unreasonable fit for USGS_13062500: a * b = -0.2023
# USGS_13062500
# Unreasonable fit for USGS_13062500: a * b = -0.0320
# USGS_13062500
# Unreasonable fit for USGS_13062500: a * b = -0.0343
# ... processing 925/930 ...USGS_14321000
# Unreasonable fit for USGS_14321000: a * b = -0.3839
# USGS_14321000
# Unreasonable fit for USGS_14321000: a * b = -0.3940
# USGS_14321000
# Unreasonable fit for USGS_14321000: a * b = -0.4039
# USGS_14321000
# Unreasonable fit for USGS_14321000: a * b = -0.4864
# ... processing 930/930 ...done
