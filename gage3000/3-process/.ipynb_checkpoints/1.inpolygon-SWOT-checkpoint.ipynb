# %%
import pandas as pd
import geopandas as gpd
import glob
import os
from concurrent.futures import ProcessPoolExecutor, as_completed
from functools import partial

data_v = 'VersionC'
# 设定日期范围
date_start = '20230801'
date_end   = '20250730'

def process_single_csv(csv_file, polygon_gdf, csv_path):
    """处理单个CSV文件的函数（用于并行处理）"""
    try:
        # 读取CSV文件
        df = pd.read_csv(csv_file)
        
        # 创建点的GeoDataFrame
        points_gdf = gpd.GeoDataFrame(
            df, 
            geometry=gpd.points_from_xy(df.lon, df.lat),
            crs="EPSG:4326"
        )
        
        # 空间连接
        joined_gdf = gpd.sjoin(points_gdf, polygon_gdf, how='inner', predicate='within')
        
        if not joined_gdf.empty:
            print(f"处理完成: {os.path.basename(csv_file)}, 匹配到 {len(joined_gdf)} 个点")
            return joined_gdf
        else:
            print(f"处理完成: {os.path.basename(csv_file)}, 没有匹配的点")
            return None
    except Exception as e:
        print(f"处理 {csv_file} 时出错: {str(e)}")
        return None

def main():
    polygon_file = '../1-buffer-match/GAGE_3000points_MERIT_Basin_buffer_polygon_4widths.shp'
    if data_v == 'VersionD':
        csv_path = '/shared5/RESEARCH_DATA/SWOT/VersionD/processed'
    elif data_v == 'VersionC':
        csv_path = '/shared5/RESEARCH_DATA/SWOT/VersionC/processed'
    
    # 读取多边形数据（只读一次）
    print("读取多边形数据...")
    polygon_df = gpd.read_file(polygon_file)
    polygon_gdf = polygon_df[['stationid', 'COMID', 'geometry']].copy()
    
    # 坐标系处理
    if polygon_gdf.crs is None:
        polygon_gdf.set_crs("EPSG:4326", inplace=True)
    elif str(polygon_gdf.crs) != "EPSG:4326":
        polygon_gdf = polygon_gdf.to_crs("EPSG:4326")
    
    # 创建空间索引以加速空间查询
    print("创建空间索引...")
    polygon_gdf.sindex
    
    # 获取所有CSV文件
    all_csv_files = glob.glob(os.path.join(csv_path, 'node*.csv'))

    csv_files = sorted([
        f for f in all_csv_files
        if date_start <= os.path.basename(f).split('_')[1].replace('.csv', '') <= date_end
    ])
    print(f"找到 {len(csv_files)} 个CSV文件")
    
    # 使用多进程并行处理
    all_results = []
    max_workers = min(os.cpu_count() - 1, len(csv_files))  # 保留一个核心给系统
    
    print(f"使用 {max_workers} 个进程并行处理...")
    
    with ProcessPoolExecutor(max_workers=max_workers) as executor:
        # 提交所有任务
        future_to_csv = {
            executor.submit(process_single_csv, csv_file, polygon_gdf, csv_path): csv_file 
            for csv_file in csv_files
        }
        
        # 收集结果
        for future in as_completed(future_to_csv):
            result = future.result()
            if result is not None:
                all_results.append(result)
    
    # 合并所有结果并保存
    if all_results:
        print("合并所有结果...")
        final_result = pd.concat(all_results, ignore_index=True)

        final_result['date'] = pd.to_datetime('2000-01-01') + pd.to_timedelta(final_result['time'], unit='s')
        final_result['date'] = final_result['date'].dt.date
        
        # 删除geometry列以节省空间（如果不需要）
        if 'geometry' in final_result.columns:
            final_result = final_result.drop(columns=['geometry'])
        
        output_file = os.path.join('./', f"1.all_matched_points_{data_v}.csv")
        final_result.to_csv(output_file, index=False)
        print(f"所有结果已保存到: {output_file}, 总共匹配到 {len(final_result)} 个点")
    else:
        print("没有找到任何匹配的点")

if __name__ == "__main__":
    main()
# Out:
# 读取多边形数据...
# 创建空间索引...
# 找到 631 个CSV文件
# 使用 79 个进程并行处理...
# 处理完成: node_20230815.csv, 没有匹配的点
# 处理完成: node_20230820.csv, 匹配到 18 个点
# 处理完成: node_20230813.csv, 没有匹配的点
# 处理完成: node_20230814.csv, 没有匹配的点
# 处理完成: node_20230812.csv, 匹配到 19 个点
# 处理完成: node_20230817.csv, 没有匹配的点
# 处理完成: node_20230819.csv, 匹配到 7 个点
# 处理完成: node_20230927.csv, 匹配到 24 个点
# 处理完成: node_20230818.csv, 没有匹配的点
# 处理完成: node_20230821.csv, 匹配到 104 个点
# 处理完成: node_20230825.csv, 匹配到 207 个点
# 处理完成: node_20230904.csv, 匹配到 216 个点
# 处理完成: node_20230829.csv, 匹配到 258 个点
# 处理完成: node_20230908.csv, 匹配到 276 个点
# 处理完成: node_20230909.csv, 匹配到 292 个点
# 处理完成: node_20230903.csv, 匹配到 195 个点
# 处理完成: node_20230831.csv, 匹配到 262 个点
# 处理完成: node_20230907.csv, 匹配到 329 个点
# 处理完成: node_20230913.csv, 匹配到 194 个点
# 处理完成: node_20230902.csv, 匹配到 228 个点
# 处理完成: node_20230826.csv, 匹配到 301 个点
# 处理完成: node_20230827.csv, 匹配到 303 个点
# 处理完成: node_20230910.csv, 匹配到 258 个点
# 处理完成: node_20230905.csv, 匹配到 331 个点
# 处理完成: node_20230914.csv, 匹配到 203 个点
# 处理完成: node_20230906.csv, 匹配到 332 个点
# 处理完成: node_20230828.csv, 匹配到 259 个点
# 处理完成: node_20230822.csv, 匹配到 269 个点
# 处理完成: node_20230824.csv, 匹配到 204 个点
# 处理完成: node_20230901.csv, 匹配到 256 个点
# 处理完成: node_20230823.csv, 匹配到 209 个点
# 处理完成: node_20230911.csv, 匹配到 222 个点
# 处理完成: node_20230830.csv, 匹配到 261 个点
# 处理完成: node_20230912.csv, 匹配到 265 个点
# 处理完成: node_20230811.csv, 匹配到 229 个点
# 处理完成: node_20230808.csv, 匹配到 204 个点
# 处理完成: node_20230809.csv, 匹配到 215 个点
# 处理完成: node_20230810.csv, 匹配到 316 个点
# 处理完成: node_20231015.csv, 匹配到 277 个点
# 处理完成: node_20230921.csv, 匹配到 268 个点
# 处理完成: node_20230807.csv, 匹配到 290 个点
# 处理完成: node_20231016.csv, 匹配到 256 个点
# 处理完成: node_20230919.csv, 匹配到 313 个点
# 处理完成: node_20230918.csv, 匹配到 344 个点
# 处理完成: node_20231001.csv, 匹配到 324 个点
# 处理完成: node_20230920.csv, 匹配到 277 个点
# 处理完成: node_20231005.csv, 匹配到 245 个点
# 处理完成: node_20230930.csv, 匹配到 469 个点
# 处理完成: node_20231009.csv, 匹配到 346 个点
# 处理完成: node_20230917.csv, 匹配到 443 个点
# 处理完成: node_20230929.csv, 匹配到 421 个点
# 处理完成: node_20231006.csv, 匹配到 281 个点
# 处理完成: node_20231010.csv, 匹配到 426 个点
# 处理完成: node_20230915.csv, 匹配到 281 个点
# 处理完成: node_20231004.csv, 匹配到 281 个点
# 处理完成: node_20231013.csv, 匹配到 277 个点
# 处理完成: node_20231012.csv, 匹配到 374 个点
# 处理完成: node_20231011.csv, 匹配到 384 个点
# 处理完成: node_20230806.csv, 匹配到 475 个点
# 处理完成: node_20231002.csv, 匹配到 312 个点
# 处理完成: node_20230928.csv, 匹配到 403 个点
# 处理完成: node_20231014.csv, 匹配到 298 个点
# 处理完成: node_20230916.csv, 匹配到 397 个点
# 处理完成: node_20231020.csv, 匹配到 466 个点
# 处理完成: node_20231008.csv, 匹配到 458 个点
# 处理完成: node_20231025.csv, 匹配到 231 个点
# 处理完成: node_20231021.csv, 匹配到 468 个点
# 处理完成: node_20231003.csv, 匹配到 287 个点
# 处理完成: node_20231225.csv, 匹配到 17 个点
# 处理完成: node_20231226.csv, 匹配到 20 个点
# 处理完成: node_20231017.csv, 匹配到 442 个点
# 处理完成: node_20231019.csv, 匹配到 408 个点
# 处理完成: node_20231007.csv, 匹配到 519 个点
# 处理完成: node_20231022.csv, 匹配到 358 个点
# 处理完成: node_20231018.csv, 匹配到 380 个点
# 处理完成: node_20231227.csv, 匹配到 17 个点
# 处理完成: node_20231026.csv, 匹配到 279 个点
# 处理完成: node_20231101.csv, 匹配到 461 个点
# 处理完成: node_20231024.csv, 匹配到 288 个点
# 处理完成: node_20231030.csv, 匹配到 401 个点
# 处理完成: node_20230804.csv, 匹配到 316 个点
# 处理完成: node_20231027.csv, 匹配到 329 个点
# 处理完成: node_20231023.csv, 匹配到 330 个点
# 处理完成: node_20231126.csv, 匹配到 210 个点
# 处理完成: node_20231029.csv, 匹配到 457 个点
# 处理完成: node_20230801.csv, 匹配到 304 个点
# 处理完成: node_20231028.csv, 匹配到 519 个点
# 处理完成: node_20231031.csv, 匹配到 429 个点
# 处理完成: node_20231102.csv, 匹配到 385 个点
# 处理完成: node_20231104.csv, 匹配到 279 个点
# 处理完成: node_20231110.csv, 匹配到 436 个点
# 处理完成: node_20231116.csv, 匹配到 270 个点
# 处理完成: node_20230802.csv, 匹配到 286 个点
# 处理完成: node_20231111.csv, 匹配到 488 个点
# 处理完成: node_20231106.csv, 匹配到 322 个点
# 处理完成: node_20231115.csv, 匹配到 264 个点
# 处理完成: node_20231105.csv, 匹配到 323 个点
# 处理完成: node_20231114.csv, 匹配到 274 个点
# 处理完成: node_20231113.csv, 匹配到 315 个点
# 处理完成: node_20230805.csv, 匹配到 428 个点处理完成: node_20231120.csv, 匹配到 439 个点
#
# 处理完成: node_20231125.csv, 匹配到 302 个点
# 处理完成: node_20231103.csv, 匹配到 347 个点
# 处理完成: node_20231117.csv, 匹配到 317 个点
# 处理完成: node_20231121.csv, 匹配到 389 个点
# 处理完成: node_20231122.csv, 匹配到 428 个点
# 处理完成: node_20231216.csv, 匹配到 211 个点
# 处理完成: node_20231112.csv, 匹配到 368 个点
# 处理完成: node_20231108.csv, 匹配到 404 个点
# 处理完成: node_20231107.csv, 匹配到 517 个点
# 处理完成: node_20231109.csv, 匹配到 413 个点
# 处理完成: node_20240116.csv, 匹配到 28 个点
# 处理完成: node_20231119.csv, 匹配到 421 个点
# 处理完成: node_20231123.csv, 匹配到 371 个点
# 处理完成: node_20231118.csv, 匹配到 521 个点
# 处理完成: node_20231124.csv, 匹配到 317 个点
# 处理完成: node_20231130.csv, 匹配到 386 个点
# 处理完成: node_20231223.csv, 匹配到 239 个点
# 处理完成: node_20231128.csv, 匹配到 451 个点
# 处理完成: node_20231129.csv, 匹配到 405 个点
# 处理完成: node_20230803.csv, 匹配到 276 个点
# 处理完成: node_20231201.csv, 匹配到 393 个点
# 处理完成: node_20231224.csv, 匹配到 215 个点
# 处理完成: node_20231202.csv, 匹配到 432 个点
# 处理完成: node_20231228.csv, 匹配到 253 个点
# 处理完成: node_20240108.csv, 匹配到 348 个点
# 处理完成: node_20231213.csv, 匹配到 352 个点
# 处理完成: node_20231204.csv, 匹配到 307 个点
# 处理完成: node_20231203.csv, 匹配到 391 个点
# 处理完成: node_20231205.csv, 匹配到 296 个点
# 处理完成: node_20231212.csv, 匹配到 389 个点
# 处理完成: node_20231207.csv, 匹配到 292 个点
# 处理完成: node_20231220.csv, 匹配到 392 个点
# 处理完成: node_20231215.csv, 匹配到 250 个点
# 处理完成: node_20231209.csv, 匹配到 509 个点
# 处理完成: node_20231221.csv, 匹配到 416 个点
# 处理完成: node_20231208.csv, 匹配到 340 个点
# 处理完成: node_20231222.csv, 匹配到 456 个点
# 处理完成: node_20231219.csv, 匹配到 495 个点
# 处理完成: node_20231217.csv, 匹配到 264 个点
# 处理完成: node_20240101.csv, 匹配到 355 个点
# 处理完成: node_20240106.csv, 匹配到 260 个点
# 处理完成: node_20231214.csv, 匹配到 360 个点
# 处理完成: node_20231218.csv, 匹配到 367 个点
# 处理完成: node_20240103.csv, 匹配到 420 个点
# 处理完成: node_20231231.csv, 匹配到 432 个点
# 处理完成: node_20240107.csv, 匹配到 279 个点
# 处理完成: node_20231206.csv, 匹配到 248 个点
# 处理完成: node_20231211.csv, 匹配到 384 个点
# 处理完成: node_20240110.csv, 匹配到 331 个点
# 处理完成: node_20240102.csv, 匹配到 371 个点
# 处理完成: node_20240318.csv, 匹配到 28 个点
# 处理完成: node_20240104.csv, 匹配到 345 个点
# 处理完成: node_20231230.csv, 匹配到 449 个点
# 处理完成: node_20240112.csv, 匹配到 444 个点
# 处理完成: node_20240105.csv, 匹配到 310 个点
# 处理完成: node_20240115.csv, 匹配到 323 个点
# 处理完成: node_20231229.csv, 匹配到 423 个点
# 处理完成: node_20240117.csv, 匹配到 233 个点
# 处理完成: node_20240111.csv, 匹配到 434 个点
# 处理完成: node_20240113.csv, 匹配到 379 个点
# 处理完成: node_20240109.csv, 匹配到 453 个点
# 处理完成: node_20231210.csv, 匹配到 407 个点
# 处理完成: node_20240114.csv, 匹配到 329 个点
# 处理完成: node_20240118.csv, 匹配到 321 个点
# 处理完成: node_20240121.csv, 匹配到 426 个点
# 处理完成: node_20240123.csv, 匹配到 262 个点
# 处理完成: node_20240122.csv, 匹配到 363 个点
# 处理完成: node_20240119.csv, 匹配到 397 个点
# 处理完成: node_20240120.csv, 匹配到 469 个点
# 处理完成: node_20240127.csv, 匹配到 305 个点
# 处理完成: node_20240124.csv, 匹配到 423 个点
# 处理完成: node_20240205.csv, 匹配到 248 个点
# 处理完成: node_20240128.csv, 匹配到 300 个点
# 处理完成: node_20240126.csv, 匹配到 300 个点
# 处理完成: node_20240201.csv, 匹配到 407 个点
# 处理完成: node_20240206.csv, 匹配到 268 个点
# 处理完成: node_20240203.csv, 匹配到 389 个点
# 处理完成: node_20240207.csv, 匹配到 232 个点
# 处理完成: node_20240209.csv, 匹配到 395 个点
# 处理完成: node_20240211.csv, 匹配到 396 个点
# 处理完成: node_20240204.csv, 匹配到 309 个点
# 处理完成: node_20240131.csv, 匹配到 401 个点
# 处理完成: node_20240320.csv, 匹配到 222 个点
# 处理完成: node_20240214.csv, 匹配到 412 个点
# 处理完成: node_20240212.csv, 匹配到 394 个点
# 处理完成: node_20240208.csv, 匹配到 289 个点
# 处理完成: node_20240202.csv, 匹配到 480 个点
# 处理完成: node_20240213.csv, 匹配到 385 个点
# 处理完成: node_20240129.csv, 匹配到 412 个点
# 处理完成: node_20240130.csv, 匹配到 431 个点
# 处理完成: node_20240217.csv, 匹配到 306 个点
# 处理完成: node_20240324.csv, 匹配到 355 个点
# 处理完成: node_20240215.csv, 匹配到 326 个点
# 处理完成: node_20240210.csv, 匹配到 494 个点
# 处理完成: node_20240218.csv, 匹配到 262 个点
# 处理完成: node_20240321.csv, 匹配到 274 个点
# 处理完成: node_20240322.csv, 匹配到 279 个点
# 处理完成: node_20240216.csv, 匹配到 313 个点
# 处理完成: node_20240223.csv, 匹配到 503 个点
# 处理完成: node_20240331.csv, 匹配到 271 个点
# 处理完成: node_20240222.csv, 匹配到 451 个点
# 处理完成: node_20240325.csv, 匹配到 384 个点
# 处理完成: node_20240329.csv, 匹配到 282 个点
# 处理完成: node_20240326.csv, 匹配到 366 个点
# 处理完成: node_20240221.csv, 匹配到 413 个点
# 处理完成: node_20240323.csv, 匹配到 420 个点
# 处理完成: node_20240224.csv, 匹配到 349 个点
# 处理完成: node_20240512.csv, 没有匹配的点
# 处理完成: node_20240219.csv, 匹配到 439 个点
# 处理完成: node_20240327.csv, 匹配到 362 个点
# 处理完成: node_20240227.csv, 匹配到 263 个点
# 处理完成: node_20240225.csv, 匹配到 259 个点
# 处理完成: node_20240401.csv, 匹配到 307 个点
# 处理完成: node_20240315.csv, 匹配到 413 个点
# 处理完成: node_20240316.csv, 匹配到 288 个点
# 处理完成: node_20240328.csv, 匹配到 303 个点
# 处理完成: node_20240330.csv, 匹配到 298 个点
# 处理完成: node_20240220.csv, 匹配到 528 个点
# 处理完成: node_20240319.csv, 匹配到 245 个点
# 处理完成: node_20240402.csv, 匹配到 333 个点
# 处理完成: node_20240317.csv, 匹配到 203 个点
# 处理完成: node_20240405.csv, 匹配到 455 个点
# 处理完成: node_20240404.csv, 匹配到 400 个点
# 处理完成: node_20240403.csv, 匹配到 429 个点
# 处理完成: node_20240226.csv, 匹配到 298 个点
# 处理完成: node_20240314.csv, 匹配到 381 个点
# 处理完成: node_20240304.csv, 匹配到 388 个点
# 处理完成: node_20240228.csv, 匹配到 211 个点
# 处理完成: node_20240409.csv, 匹配到 212 个点
# 处理完成: node_20240302.csv, 匹配到 429 个点
# 处理完成: node_20240303.csv, 匹配到 383 个点
# 处理完成: node_20240305.csv, 匹配到 417 个点
# 处理完成: node_20240408.csv, 匹配到 297 个点
# 处理完成: node_20240309.csv, 匹配到 339 个点
# 处理完成: node_20240406.csv, 匹配到 391 个点
# 处理完成: node_20240306.csv, 匹配到 358 个点
# 处理完成: node_20240428.csv, 匹配到 299 个点
# 处理完成: node_20240407.csv, 匹配到 298 个点
# 处理完成: node_20240229.csv, 匹配到 291 个点
# 处理完成: node_20240310.csv, 匹配到 316 个点
# 处理完成: node_20240308.csv, 匹配到 301 个点
# 处理完成: node_20240301.csv, 匹配到 475 个点
# 处理完成: node_20240313.csv, 匹配到 379 个点
# 处理完成: node_20240410.csv, 匹配到 286 个点
# 处理完成: node_20240307.csv, 匹配到 330 个点
# 处理完成: node_20240414.csv, 匹配到 353 个点
# 处理完成: node_20240312.csv, 匹配到 374 个点
# 处理完成: node_20240416.csv, 匹配到 378 个点
# 处理完成: node_20240311.csv, 匹配到 437 个点
# 处理完成: node_20240411.csv, 匹配到 295 个点
# 处理完成: node_20240419.csv, 匹配到 284 个点
# 处理完成: node_20240413.csv, 匹配到 412 个点
# 处理完成: node_20240417.csv, 匹配到 364 个点
# 处理完成: node_20240412.csv, 匹配到 471 个点
# 处理完成: node_20240415.csv, 匹配到 362 个点
# 处理完成: node_20240421.csv, 匹配到 327 个点
# 处理完成: node_20240429.csv, 匹配到 290 个点
# 处理完成: node_20240420.csv, 匹配到 338 个点
# 处理完成: node_20240425.csv, 匹配到 426 个点
# 处理完成: node_20240418.csv, 匹配到 302 个点
# 处理完成: node_20240426.csv, 匹配到 475 个点
# 处理完成: node_20240423.csv, 匹配到 370 个点
# 处理完成: node_20240427.csv, 匹配到 415 个点
# 处理完成: node_20240424.csv, 匹配到 399 个点
# 处理完成: node_20240422.csv, 匹配到 452 个点
# 处理完成: node_20240430.csv, 匹配到 254 个点
# 处理完成: node_20240504.csv, 匹配到 285 个点
# 处理完成: node_20240510.csv, 匹配到 277 个点
# 处理完成: node_20240507.csv, 匹配到 437 个点
# 处理完成: node_20240501.csv, 匹配到 274 个点
# 处理完成: node_20240505.csv, 匹配到 400 个点
# 处理完成: node_20240503.csv, 匹配到 508 个点
# 处理完成: node_20240506.csv, 匹配到 399 个点
# 处理完成: node_20240508.csv, 匹配到 399 个点
# 处理完成: node_20240509.csv, 匹配到 341 个点
# 处理完成: node_20240515.csv, 匹配到 465 个点
# 处理完成: node_20240607.csv, 匹配到 304 个点
# 处理完成: node_20240502.csv, 匹配到 355 个点
# 处理完成: node_20240530.csv, 匹配到 253 个点
# 处理完成: node_20240521.csv, 匹配到 278 个点
# 处理完成: node_20240531.csv, 匹配到 287 个点
# 处理完成: node_20240516.csv, 匹配到 468 个点
# 处理完成: node_20240518.csv, 匹配到 347 个点
# 处理完成: node_20240522.csv, 匹配到 266 个点
# 处理完成: node_20240606.csv, 匹配到 431 个点
# 处理完成: node_20240519.csv, 匹配到 335 个点
# 处理完成: node_20240524.csv, 匹配到 477 个点
# 处理完成: node_20240528.csv, 匹配到 422 个点
# 处理完成: node_20240526.csv, 匹配到 393 个点
# 处理完成: node_20240529.csv, 匹配到 357 个点
# 处理完成: node_20240513.csv, 匹配到 317 个点
# 处理完成: node_20240604.csv, 匹配到 382 个点
# 处理完成: node_20240601.csv, 匹配到 293 个点
# 处理完成: node_20240610.csv, 匹配到 284 个点
# 处理完成: node_20240611.csv, 匹配到 253 个点
# 处理完成: node_20240602.csv, 匹配到 392 个点
# 处理完成: node_20240523.csv, 匹配到 403 个点
# 处理完成: node_20240605.csv, 匹配到 413 个点
# 处理完成: node_20240514.csv, 匹配到 401 个点
# 处理完成: node_20240525.csv, 匹配到 425 个点
# 处理完成: node_20240520.csv, 匹配到 284 个点
# 处理完成: node_20240609.csv, 匹配到 310 个点
# 处理完成: node_20240615.csv, 匹配到 403 个点
# 处理完成: node_20240612.csv, 匹配到 299 个点
# 处理完成: node_20240527.csv, 匹配到 380 个点
# 处理完成: node_20240603.csv, 匹配到 440 个点
# 处理完成: node_20240616.csv, 匹配到 381 个点
# 处理完成: node_20240608.csv, 匹配到 347 个点
# 处理完成: node_20240621.csv, 匹配到 266 个点
# 处理完成: node_20240627.csv, 匹配到 443 个点
# 处理完成: node_20240622.csv, 匹配到 276 个点
# 处理完成: node_20240618.csv, 匹配到 421 个点
# 处理完成: node_20240625.csv, 匹配到 394 个点
# 处理完成: node_20240619.csv, 匹配到 349 个点
# 处理完成: node_20240614.csv, 匹配到 471 个点
# 处理完成: node_20240620.csv, 匹配到 315 个点
# 处理完成: node_20240617.csv, 匹配到 355 个点
# 处理完成: node_20240624.csv, 匹配到 446 个点
# 处理完成: node_20240613.csv, 匹配到 408 个点
# 处理完成: node_20240628.csv, 匹配到 384 个点
# 处理完成: node_20240629.csv, 匹配到 336 个点
# 处理完成: node_20240623.csv, 匹配到 398 个点
# 处理完成: node_20231127.csv, 匹配到 1009 个点
# 处理完成: node_20240517.csv, 匹配到 370 个点
# 处理完成: node_20240701.csv, 匹配到 258 个点
# 处理完成: node_20240626.csv, 匹配到 417 个点
# 处理完成: node_20240730.csv, 匹配到 90 个点
# 处理完成: node_20240706.csv, 匹配到 422 个点
# 处理完成: node_20240708.csv, 匹配到 368 个点
# 处理完成: node_20240630.csv, 匹配到 314 个点
# 处理完成: node_20240705.csv, 匹配到 460 个点
# 处理完成: node_20240713.csv, 匹配到 207 个点
# 处理完成: node_20240707.csv, 匹配到 355 个点
# 处理完成: node_20240703.csv, 匹配到 299 个点
# 处理完成: node_20240711.csv, 匹配到 305 个点
# 处理完成: node_20240709.csv, 匹配到 399 个点
# 处理完成: node_20240716.csv, 匹配到 414 个点
# 处理完成: node_20240712.csv, 匹配到 315 个点
# 处理完成: node_20240718.csv, 匹配到 447 个点
# 处理完成: node_20240710.csv, 匹配到 357 个点
# 处理完成: node_20240715.csv, 匹配到 425 个点
# 处理完成: node_20240717.csv, 匹配到 425 个点
# 处理完成: node_20240704.csv, 匹配到 417 个点
# 处理完成: node_20240714.csv, 匹配到 393 个点
# 处理完成: node_20240802.csv, 匹配到 169 个点
# 处理完成: node_20240810.csv, 匹配到 283 个点
# 处理完成: node_20240702.csv, 匹配到 354 个点
# 处理完成: node_20240805.csv, 匹配到 149 个点
# 处理完成: node_20240727.csv, 匹配到 227 个点
# 处理完成: node_20240803.csv, 匹配到 160 个点
# 处理完成: node_20240821.csv, 匹配到 318 个点
# 处理完成: node_20240729.csv, 匹配到 369 个点
# 处理完成: node_20240824.csv, 匹配到 286 个点
# 处理完成: node_20240830.csv, 匹配到 377 个点
# 处理完成: node_20240826.csv, 匹配到 352 个点
# 处理完成: node_20240828.csv, 匹配到 399 个点
# 处理完成: node_20240827.csv, 匹配到 412 个点
# 处理完成: node_20240906.csv, 匹配到 299 个点
# 处理完成: node_20240831.csv, 匹配到 285 个点
# 处理完成: node_20240822.csv, 匹配到 295 个点
# 处理完成: node_20240823.csv, 匹配到 261 个点
# 处理完成: node_20240901.csv, 匹配到 288 个点
# 处理完成: node_20240903.csv, 匹配到 279 个点
# 处理完成: node_20240728.csv, 匹配到 404 个点
# 处理完成: node_20240829.csv, 匹配到 472 个点
# 处理完成: node_20240902.csv, 匹配到 241 个点
# 处理完成: node_20240817.csv, 匹配到 257 个点
# 处理完成: node_20240726.csv, 匹配到 487 个点
# 处理完成: node_20240820.csv, 匹配到 382 个点
# 处理完成: node_20240825.csv, 匹配到 408 个点
# 处理完成: node_20240724.csv, 匹配到 290 个点
# 处理完成: node_20240814.csv, 匹配到 265 个点
# 处理完成: node_20240722.csv, 匹配到 246 个点
# 处理完成: node_20240725.csv, 匹配到 413 个点
# 处理完成: node_20240806.csv, 匹配到 343 个点
# 处理完成: node_20240816.csv, 匹配到 439 个点
# 处理完成: node_20240818.csv, 匹配到 377 个点
# 处理完成: node_20240804.csv, 匹配到 458 个点
# 处理完成: node_20240812.csv, 匹配到 295 个点
# 处理完成: node_20240807.csv, 匹配到 446 个点
# 处理完成: node_20240907.csv, 匹配到 377 个点
# 处理完成: node_20240719.csv, 匹配到 598 个点
# 处理完成: node_20240813.csv, 匹配到 268 个点
# 处理完成: node_20240819.csv, 匹配到 374 个点
# 处理完成: node_20240721.csv, 匹配到 329 个点
# 处理完成: node_20240808.csv, 匹配到 442 个点
# 处理完成: node_20240909.csv, 匹配到 428 个点
# 处理完成: node_20241109.csv, 匹配到 4 个点
# 处理完成: node_20240809.csv, 匹配到 325 个点
# 处理完成: node_20241111.csv, 没有匹配的点
# 处理完成: node_20241113.csv, 没有匹配的点
# 处理完成: node_20240905.csv, 匹配到 494 个点
# 处理完成: node_20240920.csv, 匹配到 331 个点
# 处理完成: node_20241004.csv, 匹配到 161 个点
# 处理完成: node_20240811.csv, 匹配到 346 个点
# 处理完成: node_20240908.csv, 匹配到 385 个点
# 处理完成: node_20240815.csv, 匹配到 482 个点
# 处理完成: node_20240904.csv, 匹配到 327 个点
# 处理完成: node_20240923.csv, 匹配到 231 个点
# 处理完成: node_20240919.csv, 匹配到 470 个点
# 处理完成: node_20240125.csv, 匹配到 678 个点
# 处理完成: node_20240922.csv, 匹配到 254 个点
# 处理完成: node_20240912.csv, 匹配到 275 个点
# 处理完成: node_20240916.csv, 匹配到 367 个点
# 处理完成: node_20240910.csv, 匹配到 386 个点
# 处理完成: node_20240914.csv, 匹配到 310 个点
# 处理完成: node_20240921.csv, 匹配到 284 个点
# 处理完成: node_20240723.csv, 匹配到 262 个点
# 处理完成: node_20240924.csv, 匹配到 212 个点
# 处理完成: node_20240917.csv, 匹配到 387 个点
# 处理完成: node_20241108.csv, 匹配到 234 个点
# 处理完成: node_20240918.csv, 匹配到 388 个点
# 处理完成: node_20241003.csv, 匹配到 266 个点
# 处理完成: node_20240731.csv, 匹配到 428 个点
# 处理完成: node_20240927.csv, 匹配到 317 个点
# 处理完成: node_20240925.csv, 匹配到 280 个点
# 处理完成: node_20240928.csv, 匹配到 388 个点
# 处理完成: node_20240720.csv, 匹配到 584 个点
# 处理完成: node_20240915.csv, 匹配到 461 个点
# 处理完成: node_20240929.csv, 匹配到 362 个点
# 处理完成: node_20240930.csv, 匹配到 317 个点
# 处理完成: node_20240911.csv, 匹配到 300 个点
# 处理完成: node_20240801.csv, 匹配到 457 个点
# 处理完成: node_20241216.csv, 匹配到 16 个点
# 处理完成: node_20241015.csv, 匹配到 137 个点
# 处理完成: node_20240926.csv, 匹配到 506 个点
# 处理完成: node_20241002.csv, 匹配到 299 个点
# 处理完成: node_20241001.csv, 匹配到 379 个点
# 处理完成: node_20241007.csv, 匹配到 363 个点
# 处理完成: node_20241107.csv, 匹配到 326 个点
# 处理完成: node_20241005.csv, 匹配到 323 个点
# 处理完成: node_20241006.csv, 匹配到 428 个点
# 处理完成: node_20241101.csv, 匹配到 200 个点
# 处理完成: node_20241008.csv, 匹配到 376 个点
# 处理完成: node_20241012.csv, 匹配到 276 个点
# 处理完成: node_20241013.csv, 匹配到 253 个点
# 处理完成: node_20241010.csv, 匹配到 419 个点
# 处理完成: node_20241009.csv, 匹配到 455 个点
# 处理完成: node_20241030.csv, 匹配到 345 个点
# 处理完成: node_20241011.csv, 匹配到 383 个点
# 处理完成: node_20241215.csv, 匹配到 163 个点
# 处理完成: node_20241014.csv, 匹配到 193 个点
# 处理完成: node_20240913.csv, 匹配到 337 个点
# 处理完成: node_20241104.csv, 匹配到 202 个点
# 处理完成: node_20241018.csv, 匹配到 485 个点
# 处理完成: node_20241031.csv, 匹配到 308 个点
# 处理完成: node_20241106.csv, 匹配到 291 个点
# 处理完成: node_20241119.csv, 匹配到 444 个点
# 处理完成: node_20241118.csv, 匹配到 446 个点
# 处理完成: node_20241019.csv, 匹配到 381 个点
# 处理完成: node_20241125.csv, 匹配到 255 个点
# 处理完成: node_20241120.csv, 匹配到 487 个点
# 处理完成: node_20241024.csv, 匹配到 296 个点
# 处理完成: node_20241121.csv, 匹配到 476 个点
# 处理完成: node_20241103.csv, 匹配到 238 个点
# 处理完成: node_20241124.csv, 匹配到 301 个点
# 处理完成: node_20241025.csv, 匹配到 230 个点
# 处理完成: node_20241117.csv, 匹配到 485 个点
# 处理完成: node_20241020.csv, 匹配到 437 个点
# 处理完成: node_20241122.csv, 匹配到 349 个点
# 处理完成: node_20241123.csv, 匹配到 327 个点
# 处理完成: node_20241115.csv, 匹配到 265 个点
# 处理完成: node_20241026.csv, 匹配到 332 个点
# 处理完成: node_20241021.csv, 匹配到 396 个点
# 处理完成: node_20241023.csv, 匹配到 349 个点
# 处理完成: node_20241126.csv, 匹配到 319 个点
# 处理完成: node_20241114.csv, 匹配到 320 个点
# 处理完成: node_20241129.csv, 匹配到 469 个点
# 处理完成: node_20241028.csv, 匹配到 416 个点
# 处理完成: node_20241128.csv, 匹配到 523 个点
# 处理完成: node_20241017.csv, 匹配到 520 个点
# 处理完成: node_20241027.csv, 匹配到 533 个点
# 处理完成: node_20241130.csv, 匹配到 408 个点
# 处理完成: node_20241022.csv, 匹配到 365 个点
# 处理完成: node_20241202.csv, 匹配到 427 个点
# 处理完成: node_20241206.csv, 匹配到 258 个点
# 处理完成: node_20241204.csv, 匹配到 324 个点
# 处理完成: node_20241029.csv, 匹配到 470 个点
# 处理完成: node_20241201.csv, 匹配到 404 个点
# 处理完成: node_20241205.csv, 匹配到 315 个点
# 处理完成: node_20241105.csv, 匹配到 278 个点
# 处理完成: node_20241127.csv, 匹配到 569 个点
# 处理完成: node_20241102.csv, 匹配到 363 个点
# 处理完成: node_20241016.csv, 匹配到 482 个点
# 处理完成: node_20241203.csv, 匹配到 338 个点
# 处理完成: node_20241116.csv, 匹配到 444 个点
# 处理完成: node_20241207.csv, 匹配到 445 个点
# 处理完成: node_20241112.csv, 匹配到 340 个点
# 处理完成: node_20241223.csv, 匹配到 423 个点
# 处理完成: node_20241221.csv, 匹配到 394 个点
# 处理完成: node_20241222.csv, 匹配到 414 个点
# 处理完成: node_20241229.csv, 匹配到 443 个点
# 处理完成: node_20241211.csv, 匹配到 496 个点
# 处理完成: node_20241226.csv, 匹配到 323 个点
# 处理完成: node_20241209.csv, 匹配到 439 个点
# 处理完成: node_20250102.csv, 匹配到 386 个点
# 处理完成: node_20241210.csv, 匹配到 434 个点
# 处理完成: node_20250101.csv, 匹配到 503 个点
# 处理完成: node_20241224.csv, 匹配到 436 个点
# 处理完成: node_20241227.csv, 匹配到 290 个点
# 处理完成: node_20241212.csv, 匹配到 432 个点
# 处理完成: node_20241228.csv, 匹配到 460 个点
# 处理完成: node_20241230.csv, 匹配到 427 个点
# 处理完成: node_20241225.csv, 匹配到 336 个点
# 处理完成: node_20241213.csv, 匹配到 348 个点
# 处理完成: node_20241208.csv, 匹配到 496 个点
# 处理完成: node_20250104.csv, 匹配到 301 个点
# 处理完成: node_20241214.csv, 匹配到 361 个点
# 处理完成: node_20250106.csv, 匹配到 272 个点
# 处理完成: node_20250109.csv, 匹配到 461 个点
# 处理完成: node_20250108.csv, 匹配到 497 个点
# 处理完成: node_20250110.csv, 匹配到 368 个点
# 处理完成: node_20241217.csv, 匹配到 430 个点
# 处理完成: node_20241220.csv, 匹配到 447 个点
# 处理完成: node_20241218.csv, 匹配到 452 个点
# 处理完成: node_20241219.csv, 匹配到 592 个点
# 处理完成: node_20250105.csv, 匹配到 272 个点
# 处理完成: node_20250113.csv, 匹配到 365 个点
# 处理完成: node_20250121.csv, 匹配到 471 个点
# 处理完成: node_20250130.csv, 匹配到 365 个点
# 处理完成: node_20250119.csv, 匹配到 403 个点
# 处理完成: node_20250114.csv, 匹配到 356 个点
# 处理完成: node_20250122.csv, 匹配到 489 个点
# 处理完成: node_20250127.csv, 匹配到 284 个点
# 处理完成: node_20250123.csv, 匹配到 375 个点
# 处理完成: node_20250117.csv, 匹配到 338 个点
# 处理完成: node_20250131.csv, 匹配到 378 个点
# 处理完成: node_20250118.csv, 匹配到 445 个点
# 处理完成: node_20250116.csv, 匹配到 331 个点
# 处理完成: node_20250212.csv, 匹配到 478 个点
# 处理完成: node_20250126.csv, 匹配到 279 个点
# 处理完成: node_20250125.csv, 匹配到 294 个点
# 处理完成: node_20250222.csv, 匹配到 374 个点
# 处理完成: node_20250206.csv, 匹配到 303 个点
# 处理完成: node_20250201.csv, 匹配到 428 个点
# 处理完成: node_20250205.csv, 匹配到 295 个点
# 处理完成: node_20250107.csv, 匹配到 315 个点
# 处理完成: node_20250209.csv, 匹配到 390 个点
# 处理完成: node_20250129.csv, 匹配到 518 个点
# 处理完成: node_20250115.csv, 匹配到 317 个点
# 处理完成: node_20250213.csv, 匹配到 402 个点
# 处理完成: node_20250202.csv, 匹配到 464 个点
# 处理完成: node_20250103.csv, 匹配到 306 个点
# 处理完成: node_20250223.csv, 匹配到 447 个点
# 处理完成: node_20250203.csv, 匹配到 403 个点
# 处理完成: node_20250128.csv, 匹配到 333 个点
# 处理完成: node_20250207.csv, 匹配到 327 个点
# 处理完成: node_20250216.csv, 匹配到 255 个点
# 处理完成: node_20250217.csv, 匹配到 304 个点
# 处理完成: node_20250124.csv, 匹配到 304 个点
# 处理完成: node_20250204.csv, 匹配到 384 个点
# 处理完成: node_20250214.csv, 匹配到 326 个点
# 处理完成: node_20250208.csv, 匹配到 456 个点
# 处理完成: node_20250120.csv, 匹配到 404 个点
# 处理完成: node_20250210.csv, 匹配到 458 个点
# 处理完成: node_20250218.csv, 匹配到 339 个点
# 处理完成: node_20250226.csv, 匹配到 318 个点
# 处理完成: node_20250215.csv, 匹配到 291 个点
# 处理完成: node_20250211.csv, 匹配到 419 个点
# 处理完成: node_20250221.csv, 匹配到 409 个点
# 处理完成: node_20250503.csv, 没有匹配的点
# 处理完成: node_20250302.csv, 匹配到 439 个点
# 处理完成: node_20250227.csv, 匹配到 359 个点
# 处理完成: node_20250225.csv, 匹配到 319 个点
# 处理完成: node_20250219.csv, 匹配到 618 个点
# 处理完成: node_20250304.csv, 匹配到 442 个点
# 处理完成: node_20250228.csv, 匹配到 341 个点
# 处理完成: node_20250303.csv, 匹配到 346 个点
# 处理完成: node_20250301.csv, 匹配到 483 个点
# 处理完成: node_20250318.csv, 匹配到 312 个点
# 处理完成: node_20250220.csv, 匹配到 642 个点
# 处理完成: node_20250320.csv, 匹配到 341 个点
# 处理完成: node_20250306.csv, 匹配到 425 个点
# 处理完成: node_20250305.csv, 匹配到 476 个点
# 处理完成: node_20250307.csv, 匹配到 349 个点
# 处理完成: node_20250314.csv, 匹配到 443 个点
# 处理完成: node_20250317.csv, 匹配到 351 个点
# 处理完成: node_20250319.csv, 匹配到 314 个点
# 处理完成: node_20250315.csv, 匹配到 419 个点
# 处理完成: node_20250316.csv, 匹配到 445 个点
# 处理完成: node_20250313.csv, 匹配到 447 个点
# 处理完成: node_20250309.csv, 匹配到 286 个点
# 处理完成: node_20250322.csv, 匹配到 451 个点
# 处理完成: node_20250321.csv, 匹配到 321 个点
# 处理完成: node_20250312.csv, 匹配到 582 个点
# 处理完成: node_20250308.csv, 匹配到 323 个点
# 处理完成: node_20250224.csv, 匹配到 438 个点
# 处理完成: node_20250310.csv, 匹配到 378 个点
# 处理完成: node_20250311.csv, 匹配到 445 个点
# 处理完成: node_20250323.csv, 匹配到 456 个点
# 处理完成: node_20250325.csv, 匹配到 555 个点
# 处理完成: node_20250329.csv, 匹配到 312 个点
# 处理完成: node_20250324.csv, 匹配到 601 个点
# 处理完成: node_20250326.csv, 匹配到 418 个点
# 处理完成: node_20250327.csv, 匹配到 435 个点
# 处理完成: node_20250330.csv, 匹配到 305 个点
# 处理完成: node_20250328.csv, 匹配到 374 个点
# 处理完成: node_20250426.csv, 匹配到 266 个点
# 处理完成: node_20250404.csv, 匹配到 387 个点
# 处理完成: node_20250403.csv, 匹配到 456 个点
# 处理完成: node_20250423.csv, 匹配到 381 个点
# 处理完成: node_20250406.csv, 匹配到 471 个点
# 处理完成: node_20250428.csv, 匹配到 309 个点
# 处理完成: node_20250424.csv, 匹配到 323 个点
# 处理完成: node_20250416.csv, 匹配到 330 个点
# 处理完成: node_20250415.csv, 匹配到 490 个点
# 处理完成: node_20250414.csv, 匹配到 442 个点
# 处理完成: node_20250407.csv, 匹配到 371 个点
# 处理完成: node_20250419.csv, 匹配到 299 个点
# 处理完成: node_20250413.csv, 匹配到 440 个点
# 处理完成: node_20250425.csv, 匹配到 414 个点
# 处理完成: node_20250421.csv, 匹配到 314 个点
# 处理完成: node_20250430.csv, 匹配到 311 个点
# 处理完成: node_20250418.csv, 匹配到 339 个点
# 处理完成: node_20250427.csv, 匹配到 365 个点
# 处理完成: node_20250420.csv, 匹配到 281 个点处理完成: node_20250410.csv, 匹配到 319 个点
#
# 处理完成: node_20250412.csv, 匹配到 491 个点
# 处理完成: node_20250409.csv, 匹配到 372 个点
# 处理完成: node_20250411.csv, 匹配到 434 个点
# 处理完成: node_20250422.csv, 匹配到 407 个点
# 处理完成: node_20250331.csv, 匹配到 351 个点
# 处理完成: node_20250417.csv, 匹配到 396 个点
# 处理完成: node_20250401.csv, 匹配到 599 个点
# 处理完成: node_20250402.csv, 匹配到 656 个点
# 处理完成: node_20250429.csv, 匹配到 346 个点
# 处理完成: node_20250501.csv, 匹配到 323 个点
# 处理完成: node_20250502.csv, 匹配到 454 个点
# 处理完成: node_20250408.csv, 匹配到 389 个点
# 处理完成: node_20250405.csv, 匹配到 445 个点
# 合并所有结果...
# 所有结果已保存到: ./1.all_matched_points_VersionC.csv, 总共匹配到 221331 个点
