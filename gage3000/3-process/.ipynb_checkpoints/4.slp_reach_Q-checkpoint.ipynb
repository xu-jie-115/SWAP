# %%
import pandas as pd
reach_slp = pd.read_csv('3.swot_slope.csv')[['reach_id','date','slope']]
q_slp = pd.read_csv('~/device5/202507-SWOT-comp-diff-alg/6.slope_all.csv')[['reach_id','time','momma_slope']]
reach_slp = reach_slp.rename(columns = {'slope':'reach_slp'})
q_slp = q_slp.rename(columns = {'momma_slope':'q_slp','time':'date'})
print(q_slp['date'])
print(reach_slp['date'])
slp_df = reach_slp.merge(q_slp,on= ['reach_id','date'], how = 'left')
slp_df.to_csv('4.slp.csv')
# Out:
# 0        2024-02-17
# 1        2024-04-20
# 2        2024-05-31
# 3        2024-06-21
# 4        2023-12-03
#             ...
# 11291    2023-06-08
# 11292    2023-06-22
# 11293    2023-06-24
# 11294    2023-06-26
# 11295    2023-07-01
# Name: date, Length: 11296, dtype: object
# 0       2025-03-29 13:13:35.542000055
# 1       2025-03-29 13:13:35.330000043
# 2       2025-03-29 13:13:35.615000010
# 3       2025-03-29 13:13:45.000000000
# 4       2025-03-29 13:13:45.027999997
#                     ...
# 1406    2025-03-04 16:27:46.759999990
# 1407    2025-03-04 01:45:06.008000016
# 1408    2025-03-04 01:45:06.149000049
# 1409    2025-03-04 01:44:26.858000040
# 1410    2025-03-04 18:11:19.434000015
# Name: date, Length: 1411, dtype: object
#          reach_id                           date  reach_slp  q_slp
# 0     74294400161  2025-03-29 13:13:35.542000055   0.001067    NaN
# 1     74294400171  2025-03-29 13:13:35.330000043   0.001089    NaN
# ...
