# %%
#替换了q50_weighted文件，并调整了高点范围，主要是river width和q50时间尺度的匹配。
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
from scipy.optimize import least_squares
import os
import warnings
warnings.filterwarnings('ignore')

R_list = np.array([0.5,1,2])
GAP_list = np.array([-0.1,0,0.1])
W_list = np.array([0.3,0.5,0.7])

# wse = wse0 + a * width**b
# return array of redisuals
def PowerFunc(params, X, y):
    wse0, a, b = params
    return y - (wse0 + a * X**b)

# soft_l1, z=residual^2
# 'weight' for swot points, low and high point equally divide remaining weight
def Loss(z):
    rho = np.zeros(3*len(z)).reshape(3,-1)
    rho[0] = 2 * ((1 + z)**0.5 - 1)
    rho[1] = (1 + z)**(-0.5)
    rho[2] = -0.5 * (1 + z)**(-1.5)
    rho[:,0] *= (len(z) - 2) / weight * (1 - weight) / 2  # (1-SWOT_weight)/2 for low point
    rho[:,1] *= (len(z) - 2) / weight * (1 - weight) / 2  # (1-SWOT_weight)/2 for high point
    return rho


df_s3all = pd.read_csv('swot_s3.csv')
df_s3all = df_s3all.drop_duplicates(subset=['stationid','time'], keep='first')
df_attr = pd.read_csv('gages3000_GRFR_q50_slp.csv')
df_q50_weighted = pd.read_csv('q50_weighted.csv')
df_attr = df_attr.merge(df_q50_weighted[['stationid','q50_weighted']],on ='stationid',how='inner')
df_attr = df_attr.drop_duplicates(subset='COMID', keep='first')
df_attr = df_attr.set_index('COMID')

df_w = pd.read_csv('1_3_w50.csv', index_col='stationid')

df_res = df_s3all.drop_duplicates('stationid')
df_res = df_res[['stationid','COMID']]
df_res = pd.concat([df_res]*(len(R_list)*len(GAP_list)*len(W_list)), ignore_index=True)
df_res = df_res.sort_values('stationid')
stationids = df_res['stationid'].unique()
df_res['R'] = R_list[np.tile(np.repeat(np.arange(len(R_list)), len(GAP_list)*len(W_list)), len(stationids))]
df_res['GAP'] = GAP_list[np.tile(np.repeat(np.arange(len(GAP_list)), len(W_list)), len(R_list)*len(stationids))]
df_res['W'] = W_list[np.tile(np.arange(len(W_list)), len(GAP_list)*len(R_list)*len(stationids))]
df_res = df_res.set_index(['stationid','R','GAP','W'])

#breakpoint()
q50, w50, slp, weight = None, None, None, None
for s in stationids[:]:
    print('\r... processing %d/%d ...'%(np.where(stationids==s)[0][0]+1, len(stationids)), end='')
    df_s3: pd.DataFrame = df_s3all[df_s3all['stationid']==s]
    st, comid = df_s3.loc[df_s3.index[0],['stationid','COMID']]
    q50 = df_attr.loc[comid,'q50_weighted']
    slp = df_attr.loc[comid,'slope']
    w50, w_low, w_high = df_w.loc[s,['w50','w_low','w_high']]
    d_bankfull = 0.27 * (w_high / 7.2)**0.6

    # calculate h50
    df_s3['w50_diff'] = np.abs(df_s3['width'] - w50)
    df_s3 = df_s3.sort_values('w50_diff')
    xdata = df_s3.iloc[:5]['width'].values
    ydata = df_s3.iloc[:5]['wse'].values
    xdata_uni = np.unique(df_s3.iloc[:5]['width'].values)  # 选择唯一的宽度值
    if len(xdata_uni) < 2:
        print("无法进行回归，宽度值过于相似")
        print(df_s3)
    else:
        ydata = df_s3.iloc[:5]['wse'].values
        res = linregress(xdata, ydata)
        if res[0] >= 0:
            h50 = res[0] * w50 + res[1]
        else:
            h50 = df_s3.iloc[:5]['wse'].mean()


    # calculate a50, h_low, h_high
    df_s4 = df_s3[(df_s3['width']>=w_low) & (df_s3['width']<=w_high)]
    if len(df_s4) < 3: continue
        
    swot_wsemax = df_s4.sort_values('wse', ascending=False).iloc[0]
    d_wsemax = 0.27 * (swot_wsemax['width'] / 7.2)**0.6
    # solve (a50 / w50)**(2/3) * slp**(1/2) / 0.035 * a50 = q50
    a50 = (q50 * 0.035 / slp**(1/2) * w50**(2/3))**(3/5)

    for r_low in R_list:
        for gap in GAP_list:
            for weight in W_list:
                # suppose channel below median can be approximated by d = a * w**R
                # solve a50 = a * w50**R * w50 - a / (R+1) * w50**(R+1)
                a_low = a50 * (r_low+1) / r_low / w50**(r_low+1)
                h0 = h50 - a_low * w50**r_low
                h_low = h0 + a_low * w_low**r_low
                h_high = swot_wsemax['wse'] + (d_bankfull - d_wsemax) + gap * d_bankfull

                # fit
                xdata = df_s4['width'].values
                ydata = df_s4['wse'].values
                a_default = (h_high - h0) / w_high**2
                xdata = np.insert(xdata, 0, [w_low,w_high])
                ydata = np.insert(ydata, 0, [h_low,h_high])
                try:
                    ls = least_squares(PowerFunc, x0=[h0,a_default,2], loss=Loss, args=(xdata,ydata))
                except:
                    breakpoint()
                df_res.loc[(s,r_low,gap,weight),['wse0','a','b']] = ls.x
                df_res.loc[(s,r_low,gap,weight),['a50','w50','q50']] = [a50, w50, q50]
                df_res.loc[(s,r_low,gap,weight),['w_low','w_high','h_low','h_high','slp']] = [w_low, w_high, h_low, h_high, slp]

df_res = df_res.dropna()
df_res.to_csv('3/fit_proba_modified_q50.csv')
print('done')
# Out:
# ... processing 2/1553 ...无法进行回归，宽度值过于相似
#             COMID         stationid         node_id       wse  wse_u  \
# 15799  56034138.0  Australia_121001  56330000130021  77.50253  0.354
#
#            width   width_u          time  w50_diff
# 15799  20.844818  1.175747  7.586496e+08  24.92251
# ... processing 4/1553 ...无法进行回归，宽度值过于相似
#             COMID         stationid         node_id      wse   wse_u  \
# 22827  56145405.0  Australia_208004  56391600060541  9.90515  0.1212
#
#            width   width_u          time   w50_diff
# 22827  50.751755  4.640247  7.574930e+08  20.068819
# ... processing 9/1553 ...无法进行回归，宽度值过于相似
#             COMID        stationid         node_id       wse    wse_u  \
# 22570  62058691.0  Brazil_10200000  62297600200331  89.54247  0.20488
#
#            width   width_u          time   w50_diff
# 22570  146.81032  3.097321  7.520935e+08  78.986857
# ... processing 27/1553 ...无法进行回归，宽度值过于相似
#             COMID        stationid         node_id        wse   wse_u  \
# 17154  62089269.0  Brazil_12600001  62296401320221  166.54757  0.2541
#
#            width   width_u          time   w50_diff
# 17154  75.373281  1.889258  7.664286e+08  24.251614
# ... processing 225/1553 ...无法进行回归，宽度值过于相似
#             COMID        stationid         node_id        wse    wse_u  \
# 22112  63045485.0  Brazil_58096000  63580900480871  577.25825  0.31964
#
#            width   width_u          time   w50_diff
# 22112  10.914591  0.824913  7.663357e+08  53.032699
# ... processing 242/1553 ...无法进行回归，宽度值过于相似
#            COMID        stationid         node_id        wse    wse_u  \
# 7327  64005735.0  Brazil_60030000  64289900160501  744.14008  0.12094
#
#           width   width_u          time   w50_diff
# 7327  83.250671  5.698078  7.742788e+08  37.782549
# ... processing 253/1553 ...无法进行回归，宽度值过于相似
#             COMID        stationid         node_id        wse    wse_u  \
# 18992  64023296.0  Brazil_61425000  64298000350481  778.34604  0.11312
#
#             width   width_u          time   w50_diff
# 18992  135.496963  4.652881  7.519141e+08  86.595932
# ... processing 254/1553 ...无法进行回归，宽度值过于相似
#             COMID        stationid         node_id        wse    wse_u  \
# 22113  64023612.0  Brazil_61510000  64298000580051  830.80205  0.16874
#
#             width    width_u          time    w50_diff
# 22113  267.088293  11.713449  7.589127e+08  231.311103
# ... processing 260/1553 ...无法进行回归，宽度值过于相似
#            COMID        stationid         node_id        wse    wse_u  \
# 4851  64025925.0  Brazil_61884002  64294700050281  600.37866  0.28555
#
#           width  width_u          time   w50_diff
# 4851  17.009179  1.22602  7.618722e+08  19.097898
# ... processing 272/1553 ...无法进行回归，宽度值过于相似
#            COMID        stationid         node_id        wse    wse_u  \
# 2396  64038317.0  Brazil_64447000  64262000390251  772.68818  0.12944
#
#           width   width_u          time  w50_diff
# 2396  61.924936  4.447676  7.510167e+08  20.56992
# ... processing 328/1553 ...无法进行回归，宽度值过于相似
#            COMID        stationid         node_id        wse    wse_u  \
# 5904  64007227.0  Brazil_66845000  64247801810711  228.18028  0.10026
#
#            width    width_u          time    w50_diff
# 5904  152.500995  13.732429  7.666816e+08  112.282304
# ... processing 334/1553 ...无法进行回归，宽度值过于相似
#             COMID        stationid         node_id        wse    wse_u  \
# 25098  64047505.0  Brazil_72715000  64187900750661  774.43359  0.36983
#
#           width   width_u          time   w50_diff
# 25098  13.71198  0.742809  7.591721e+08  26.082769
# ... processing 371/1553 ...无法进行回归，宽度值过于相似
#             COMID        stationid         node_id        wse    wse_u  \
# 22686  64056228.0  Brazil_86440000  64120200660171  293.25531  0.17081
#
#             width   width_u          time   w50_diff
# 22686  143.599341  4.660882  7.681857e+08  62.906059
# ... processing 377/1553 ...无法进行回归，宽度值过于相似
#             COMID        stationid         node_id        wse   wse_u  \
# 10333  64065171.0  Brazil_87590000  64130000220681  118.59043  0.1288
#
#            width   width_u          time  w50_diff
# 10333  46.368797  3.826588  7.682721e+08  1.493763
# ... processing 501/1553 ...无法进行回归，宽度值过于相似
#             COMID       stationid         node_id        wse    wse_u  \
# 21745  66014427.0  Chile_07354001  66240000930311  257.10984  0.14731
#
#            width    width_u          time    w50_diff
# 21745  181.61553  10.722736  7.590444e+08  104.559024
# ... processing 502/1553 ...无法进行回归，宽度值过于相似
#             COMID       stationid         node_id        wse   wse_u  \
# 25489  66014429.0  Chile_07354002  66240000940021  300.83309  0.1751
#
#            width  width_u          time   w50_diff
# 25489  40.918041  3.71103  7.500309e+08  15.512138
# ... processing 506/1553 ...无法进行回归，宽度值过于相似
#             COMID       stationid         node_id        wse    wse_u  \
# 25096  66014361.0  Chile_08106002  66230000320341  435.12109  0.27699
#
#            width  width_u          time   w50_diff
# 25096  65.184468  4.42755  7.743718e+08  20.594686
# ... processing 601/1553 ...无法进行回归，宽度值过于相似
#             COMID     stationid         node_id       wse    wse_u      width  \
# 22119  14032403.0  GRDC_1813450  14580500220401  12.53228  0.14258  98.539709
#
#         width_u          time   w50_diff
# 22119  8.860834  7.504048e+08  35.969613
# ... processing 653/1553 ...无法进行回归，宽度值过于相似
#             COMID     stationid         node_id        wse    wse_u  \
# 25048  41004247.0  GRDC_2588653  41301500160131  201.20192  0.25374
#
#            width   width_u          time  w50_diff
# 25048  54.160808  3.270931  7.547921e+08  7.516107
# ... processing 669/1553 ...无法进行回归，宽度值过于相似
#             COMID     stationid         node_id       wse    wse_u      width  \
# 25170  41006810.0  GRDC_2589320  41301101980111  14.20401  0.12694  44.336148
#
#         width_u          time  w50_diff
# 25170  2.332072  7.675838e+08   0.74565
# ... processing 675/1553 ...无法进行回归，宽度值过于相似
#             COMID     stationid         node_id      wse    wse_u  \
# 25478  41005476.0  GRDC_2589390  41301105480161  4.74125  0.10256
#
#              width    width_u          time     w50_diff
# 25478  1084.308255  32.507688  7.558231e+08  1005.318869
# ... processing 806/1553 ...无法进行回归，宽度值过于相似
#             COMID     stationid         node_id        wse    wse_u  \
# 13915  74039610.0  GRDC_4122350  74292500060361  356.17162  0.13703
#
#            width   width_u         time  w50_diff
# 13915  51.738628  4.393779  768449920.0  9.798851
# ... processing 866/1553 ...无法进行回归，宽度值过于相似
#             COMID     stationid         node_id         wse    wse_u  \
# 24672  75005087.0  GRDC_4151801  75219100210101  1278.51461  0.26731
#
#              width    width_u          time     w50_diff
# 24672  2336.588877  78.885397  7.742903e+08  2294.003005
# ... processing 981/1553 ...无法进行回归，宽度值过于相似
#            COMID     stationid         node_id       wse    wse_u       width  \
# 9824  56139453.0  GRDC_5202070  56391200090491  12.16196  0.09753  249.938887
#
#         width_u          time    w50_diff
# 9824  20.245243  7.601538e+08  199.938543
# ... processing 985/1553 ...无法进行回归，宽度值过于相似
#             COMID     stationid         node_id       wse    wse_u      width  \
# 25099  52005805.0  GRDC_5231700  52174000460431  12.46907  0.21925  47.068929
#
#         width_u          time   w50_diff
# 25099  1.091928  7.724790e+08  22.188859
# ... processing 1021/1553 ...无法进行回归，宽度值过于相似
#             COMID     stationid         node_id        wse    wse_u  \
# 25488  23013515.0  GRDC_6335301  23264000610341  206.66225  0.11031
#
#             width    width_u          time    w50_diff
# 25488  316.269833  10.474895  7.730231e+08  277.864721
# ... processing 1058/1553 ...无法进行回归，宽度值过于相似
#             COMID     stationid         node_id       wse    wse_u      width  \
# 24800  23009220.0  GRDC_6421102  23250800220391  11.62934  0.11828  81.785401
#
#         width_u          time   w50_diff
# 24800  4.457101  7.709994e+08  12.435144
# ... processing 1105/1553 ...无法进行回归，宽度值过于相似
#            COMID     stationid         node_id        wse    wse_u  \
# 9744  23019645.0  GRDC_6935310  23268000230531  355.36904  0.13603
#
#            width   width_u          time   w50_diff
# 9744  120.118715  5.551614  7.703622e+08  76.534989
# ... processing 1115/1553 ...无法进行回归，宽度值过于相似
#             COMID     stationid         node_id       wse    wse_u  \
# 25039  28019763.0  GRDC_6976450  28324300010551  81.78597  0.09614
#
#             width    width_u          time    w50_diff
# 25039  577.941237  39.781954  7.709870e+08  194.923256
# ... processing 1208/1553 ...无法进行回归，宽度值过于相似
#             COMID      stationid         node_id        wse    wse_u  \
# 19879  73011043.0  USGS_02163001  73240200620561  199.00861  0.24134
#
#           width   width_u          time   w50_diff
# 19879  6.517082  0.340572  7.445827e+08  24.998908
# ... processing 1243/1553 ...无法进行回归，宽度值过于相似
#             COMID      stationid         node_id        wse    wse_u  \
# 20887  73013128.0  USGS_02337170  73260901100951  221.58958  0.29589
#
#           width   width_u          time   w50_diff
# 20887  1.737811  0.110379  7.626572e+08  30.819293
# ... processing 1260/1553 ...无法进行回归，宽度值过于相似
#             COMID      stationid         node_id       wse    wse_u  \
# 20932  73019417.0  USGS_02365500  73270200090521  14.01348  0.09361
#
#             width    width_u          time    w50_diff
# 20932  773.049133  46.789586  7.582327e+08  708.675542
# ... processing 1282/1553 ...无法进行回归，宽度值过于相似
#             COMID      stationid         node_id       wse    wse_u  \
# 23694  74069900.0  USGS_02486000  74100600320631  78.69978  0.09713
#
#            width   width_u          time  w50_diff
# 23694  93.518311  7.758837  7.664745e+08  4.835983
# ... processing 1300/1553 ...无法进行回归，宽度值过于相似
#             COMID      stationid         node_id        wse    wse_u  \
# 24664  74034632.0  USGS_03082500  74269800070831  264.55109  0.09803
#
#            width   width_u          time   w50_diff
# 24664  76.882644  7.491121  7.606341e+08  22.145074
# ... processing 1305/1553 ...无法进行回归，宽度值过于相似
#             COMID      stationid         node_id        wse    wse_u  \
# 23495  74034318.0  USGS_03146500  74269400290361  237.45402  0.09768
#
#             width    width_u          time    w50_diff
# 23495  198.645804  12.328751  7.671209e+08  159.840338
# ... processing 1306/1553 ...无法进行回归，宽度值过于相似
#             COMID      stationid         node_id        wse    wse_u  \
# 24753  74037023.0  USGS_03147500  74269400240461  214.24361  0.10969
#
#             width   width_u          time   w50_diff
# 24753  138.043535  9.952443  7.571151e+08  94.054181
# ... processing 1313/1553 ...无法进行回归，宽度值过于相似
#             COMID      stationid         node_id        wse    wse_u  \
# 20972  74034566.0  USGS_03221000  74267800250321  233.48705  0.26361
#
#            width   width_u          time  w50_diff
# 20972  41.738177  3.497684  7.554465e+08  3.892391
# ... processing 1320/1553 ...无法进行回归，宽度值过于相似
#             COMID      stationid         node_id        wse    wse_u  \
# 23680  74031754.0  USGS_03324500  74266900160231  207.08237  0.11864
#
#            width   width_u          time   w50_diff
# 23680  75.594849  5.371184  7.599488e+08  17.483706
# ... processing 1328/1553 ...无法进行回归，宽度值过于相似
#             COMID      stationid         node_id        wse    wse_u  \
# 25097  74037490.0  USGS_03351000  74266400800141  230.93367  0.30083
#
#            width   width_u          time  w50_diff
# 25097  31.639059  2.991868  7.609411e+08  4.764193
# ... processing 1359/1553 ...无法进行回归，宽度值过于相似
#            COMID      stationid         node_id        wse    wse_u  \
# 2790  72052288.0  USGS_04137005  72558200280861  239.14099  0.10483
#
#           width   width_u          time   w50_diff
# 2790  74.131456  6.677063  7.733394e+08  32.809142
# ... processing 1381/1553 ...无法进行回归，宽度值过于相似
#             COMID      stationid         node_id        wse    wse_u  \
# 11110  74026878.0  USGS_05454500  74286200050961  198.64503  0.27538
#
#           width   width_u          time   w50_diff
# 11110  8.118069  0.693639  7.493054e+08  48.318109
# ... processing 1403/1553 ...无法进行回归，宽度值过于相似
#             COMID      stationid         node_id        wse   wse_u  \
# 23612  74048225.0  USGS_05599500  74270400050321  104.44491  0.0995
#
#            width  width_u          time   w50_diff
# 23612  62.061635  5.48189  7.664356e+08  25.246178
# ... processing 1414/1553 ...无法进行回归，宽度值过于相似
#             COMID      stationid         node_id       wse    wse_u  \
# 20072  74007442.0  USGS_06335500  74297800360441  820.1588  0.22023
#
#            width   width_u          time  w50_diff
# 20072  31.465054  3.122865  7.724489e+08  6.121942
# ... processing 1415/1553 ...无法进行回归，宽度值过于相似
#             COMID      stationid         node_id      wse    wse_u      width  \
# 15139  74005821.0  USGS_06336000  74297800230491  684.337  0.15811  25.741394
#
#         width_u          time   w50_diff
# 15139  1.862975  7.694808e+08  23.917335
# ... processing 1432/1553 ...无法进行回归，宽度值过于相似
#             COMID      stationid         node_id        wse    wse_u  \
# 11463  74034309.0  USGS_06810000  74293800020411  274.62795  0.13754
#
#            width   width_u          time   w50_diff
# 11463  67.676954  6.632536  7.494783e+08  36.561487
# ... processing 1442/1553 ...无法进行回归，宽度值过于相似
#            COMID      stationid         node_id       wse   wse_u       width  \
# 7800  74061253.0  USGS_07076517  74252400060071  67.22267  0.0933  220.779184
#
#         width_u          time    w50_diff
# 7800  18.918186  7.602082e+08  181.540919
# ... processing 1455/1553 ...无法进行回归，宽度值过于相似
#             COMID      stationid         node_id        wse    wse_u  \
# 25049  74056084.0  USGS_07176000  74246000380431  169.64717  0.13513
#
#             width    width_u          time    w50_diff
# 25049  146.183961  13.459947  7.693557e+08  109.942048
# ... processing 1463/1553 ...无法进行回归，宽度值过于相似
#             COMID      stationid         node_id        wse    wse_u  \
# 13852  74065473.0  USGS_07331000  74226000170281  200.40552  0.11254
#
#            width   width_u          time   w50_diff
# 13852  54.567689  5.317343  7.441567e+08  20.547116
# ... processing 1464/1553 ...无法进行回归，宽度值过于相似
#             COMID      stationid         node_id       wse    wse_u  \
# 11025  74067107.0  USGS_07340000  74224000100891  87.53466  0.18737
#
#            width   width_u          time  w50_diff
# 11025  38.976997  1.445856  7.656638e+08   1.86709
# ... processing 1465/1553 ...无法进行回归，宽度值过于相似
#             COMID      stationid         node_id       wse    wse_u  \
# 24801  74069159.0  USGS_07348000  74223600030461  45.34375  0.23772
#
#            width   width_u          time   w50_diff
# 24801  19.285988  1.197507  7.729136e+08  17.751577
# ... processing 1474/1553 ...无法进行回归，宽度值过于相似
#             COMID      stationid         node_id       wse    wse_u  \
# 14115  75009078.0  USGS_08065350  75140100200511  50.87115  0.33813
#
#             width   width_u          time   w50_diff
# 14115  112.600947  8.715994  7.675919e+08  75.044171
# ... processing 1496/1553 ...无法进行回归，宽度值过于相似
#            COMID      stationid         node_id         wse    wse_u  \
# 1510  77020643.0  USGS_09368000  77260300310141  1486.73423  0.10375
#
#            width   width_u          time    w50_diff
# 1510  577.375204  14.61756  7.580659e+08  514.764295
# ... processing 1497/1553 ...无法进行回归，宽度值过于相似
#            COMID      stationid         node_id        wse    wse_u     width  \
# 2584  77029062.0  USGS_09510000  77222300020841  490.74091  0.30363  4.855432
#
#        width_u          time   w50_diff
# 2584  0.284863  7.464780e+08  57.063906
# ... processing 1516/1553 ...无法进行回归，宽度值过于相似
#             COMID      stationid         node_id         wse    wse_u  \
# 24929  78024058.0  USGS_13011000  78299900210581  2083.94179  0.19686
#
#              width    width_u          time     w50_diff
# 24929  1413.486103  85.963545  7.501311e+08  1365.119675
# ... processing 1538/1553 ...无法进行回归，宽度值过于相似
#             COMID      stationid         node_id        wse   wse_u  \
# 23421  78024220.0  USGS_14150000  78220000320801  183.65987  0.0937
#
#             width   width_u          time   w50_diff
# 23421  186.689871  17.34339  7.639060e+08  140.56592
# ... processing 1553/1553 ...done
