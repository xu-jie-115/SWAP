# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 20
plt.rcParams['text.color'] = '#808080'
plt.rcParams['mathtext.default'] = 'regular'
plt.rcParams['axes.facecolor'] = '#F8F8F8'
plt.rcParams['axes.titlesize'] = 24
plt.rcParams['axes.labelsize'] = 24
plt.rcParams['axes.titlepad'] = 10
plt.rcParams['axes.labelpad'] = 10

fig = plt.figure(figsize=(10,6))
ax = plt.axes([0.1,0.1,0.8,0.8])


x_swot = [6.5, 7.3, 7.6, 8.2, 7.3, 8.2, 8.6, 8.9, 7.1, 8.8] +\
         [6.3, 6.8, 8.8, 9.1, 11, 13] + [6.6, 6.7, 9.3, 9.7, 13.2]
y_swot = [4.1, 7.8, 6.2, 8.0, 7.0, 9.3, 9.6, 8.5, 6.4, 7.4] +\
         [-2, -4, 18, 16, 10.5, 10] + [11.9, 10.4, 4.3, 5, 5.6]
x_filter = [2, 6.8, 7.3, 9.3, 14.5]
y_filter = [4, 4.8, 0.5, 9, 8.5]
ax.scatter(x_swot, y_swot, color='#E02020', s=60, zorder=2)
ax.errorbar(x_swot, y_swot, xerr=np.random.uniform(0.2,0.6,21), yerr=np.random.uniform(0.4,1,21),
            fmt='none', lw=1, ecolor='#C0C0C0', zorder=0)
ax.scatter(x_filter, y_filter, color='#808080', s=60, zorder=2)
ax.errorbar(x_filter, y_filter, xerr=[1.3, 1.2, 0.4, 0.8, 2], yerr=[0.4, 2, 3, 1.8, 1.6],
            fmt='none', lw=1, ecolor='#C0C0C0', zorder=0)


# legend
ax.scatter([0.7], [18.7], color='#E02020', s=60)
ax.scatter([0.7], [16.8], color='#808080', s=60)
ax.errorbar([0.7], [14.9], xerr=[0.4], yerr=[0.6], fmt='none', lw=1, ecolor='#808080')
ax.text(1.4, 18.7, 'Qualified data', ha='left', va='center', color='black')
ax.text(1.4, 16.8, 'Removed data', ha='left', va='center', color='black')
ax.text(1.4, 14.9, 'Uncertainty', ha='left', va='center', color='black')

ax.set_xlim(0,16)
ax.set_ylim(-5,20)
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlabel('Width')
ax.set_ylabel('Elevation')
ax.set_title('Uncertainty', weight='bold', color='black')

#plt.show()
plt.savefig('fig3a.png', dpi=200)
